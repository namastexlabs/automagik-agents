# %%
import os
import psycopg2
from dotenv import load_dotenv
from rich.console import Console
from rich.table import Table
import urllib.parse

# Initialize console for rich output
console = Console()

def get_product_families():
    """
    Connect to the BlackPearl database and retrieve all product families,
    including sample products with their brand names.

    Returns:
        List of dictionaries containing product family information
    """
    # Load environment variables
    load_dotenv()

    # Get database URI from environment
    db_uri = os.getenv('BLACKPEARL_DB_URI')

    if not db_uri:
        console.print("[red]Error: BLACKPEARL_DB_URI not found in environment variables[/red]")
        return []

    # Parse the connection string
    result = urllib.parse.urlparse(db_uri)
    username = result.username
    password = result.password
    database = result.path[1:]
    hostname = result.hostname
    port = result.port

    console.print(f"[blue]Connecting to database {database} at {hostname}...[/blue]")

    conn = None  # Initialize conn to None
    try:
        # Connect to the database
        conn = psycopg2.connect(
            host=hostname,
            port=port,
            database=database,
            user=username,
            password=password,
            connect_timeout=10
        )

        # Create a cursor
        cursor = conn.cursor()

        # Query product families
        cursor.execute("""
            SELECT id, codigo, "nomeFamilia"
            FROM catalogo_familiadeproduto
            ORDER BY "nomeFamilia"
        """)

        families = cursor.fetchall()

        # Fetch all brands into a dictionary for quick lookup {brand_id: brand_name}
        cursor.execute("SELECT id, nome FROM catalogo_marca")
        brands_dict = {brand[0]: brand[1] for brand in cursor.fetchall()}


        # Convert to list of dictionaries
        result = []
        for family in families:
            family_id = family[0]
            family_name = family[2] # "nomeFamilia"

            # Get 10 sample products for each family, including brand name
            # Joining catalogo_produto (aliased p) with catalogo_marca (aliased m)
            cursor.execute("""
                SELECT p.id, p.descricao, p.descr_detalhada, p.ean, p.marca_id
                FROM catalogo_produto p
                WHERE p.familia_id = %s
                LIMIT 10
            """, (family_id,))

            sample_products_raw = cursor.fetchall()

            # Map raw product data to include brand name from the brands_dict
            products_list = []
            for p in sample_products_raw:
                brand_id = p[4]
                brand_name = brands_dict.get(brand_id, "Marca Desconhecida") # Lookup brand name
                products_list.append({
                    "id": p[0],
                    "nome": p[1], # from p.descricao
                    "descricao_detalhada": p[2], # from p.descr_detalhada
                    "ean": p[3], # from p.ean
                    "marca": brand_name # Fetched brand name
                })


            result.append({
                "id": family_id,
                "codigo": family[1],
                "nome_familia": family_name,
                "sample_products": products_list # Now includes brand name
            })

        # Display the results in a table (only family info)
        table = Table(title="Product Families")
        table.add_column("ID", style="cyan")
        table.add_column("Code", style="green")
        table.add_column("Family Name", style="yellow")

        for family_data in result:
            table.add_row(
                str(family_data["id"]),
                str(family_data["codigo"]),
                family_data["nome_familia"]
            )

        console.print(table)
        console.print(f"\n[green]Total product families: {len(result)}[/green]")

        # Close cursor and connection
        cursor.close()
        conn.close()

        return result

    except Exception as e:
        console.print(f"[red]Error during database operation:[/red] {str(e)}")
        # Ensure connection is closed even if an error occurs
        if conn:
            conn.close()
        return []

product_families = get_product_families()
print(product_families)
# Out:
# Connecting to database solidpower_db at db-postgresql-theros-do-user-19117798-0.g.db.ondigitalocean.com...
#                Product Families
# ┏━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ ID  ┃ Code        ┃ Family Name            ┃
# ┡━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 115 │ 0           │                        │
# │ 65  │ 1129682242  │ ACESSÓRIOS GABINETE    │
# │ 113 │ 10546186400 │ ACESSÓRIOS OFFICE      │
# │ 109 │ 10506555149 │ ADAPTADOR USB WIFI     │
# │ 81  │ 1129682258  │ AIR COOLER             │
# │ 85  │ 1129682262  │ APOIO PARA TECLADO     │
# │ 104 │ 7630787841  │ AUTO CARE              │
# │ 93  │ 1643432804  │ BERMUDA                │
# │ 84  │ 1129682261  │ BOARD GAMES            │
# │ 96  │ 6759916857  │ CABOS                  │
# │ 88  │ 1163533626  │ CADEIRA                │
# │ 83  │ 1129682260  │ CAIXA DE SOM           │
# │ 90  │ 1397365053  │ CAMISETA               │
# │ 91  │ 1397365071  │ CAMISOLA               │
# │ 82  │ 1129682259  │ CANETA DIGITAL         │
# │ 61  │ 1129682238  │ COMBO                  │
# │ 86  │ 1129682263  │ CONSOLE                │
# │ 99  │ 7520871400  │ DAC                    │
# │ 112 │ 10506555811 │ DOCK STATION           │
# │ 70  │ 1129682247  │ FAN                    │
# │ 80  │ 1129682257  │ FONTE                  │
# │ 79  │ 1129682256  │ GABINETE               │
# │ 78  │ 1129682255  │ HEADSET                │
# │ 111 │ 10506555697 │ HUB/SWITCH             │
# │ 102 │ 7561382514  │ ILUMINAÇÃO             │
# │ 77  │ 1129682254  │ JOYSTICK               │
# │ 60  │ 1129682237  │ KEYCAPS                │
# │ 101 │ 7537275456  │ MEMÓRIA                │
# │ 76  │ 1129682253  │ MESA DIGITALIZADORA    │
# │ 75  │ 1129682252  │ MICROFONE              │
# │ 87  │ 1129682264  │ MOBILE                 │
# │ 74  │ 1129682251  │ MOCHILA                │
# │ 73  │ 1129682250  │ MONITORES              │
# │ 72  │ 1129682249  │ MOUSE                  │
# │ 71  │ 1129682248  │ MOUSEPAD               │
# │ 114 │ 10597965118 │ NOBREAK                │
# │ 69  │ 1129682246  │ PASTA TÉRMICA          │
# │ 107 │ 10455298528 │ PC CARE                │
# │ 94  │ 1696045999  │ PELÚCIA                │
# │ 105 │ 10444013670 │ PEN DRIVE              │
# │ 89  │ 1241237250  │ PIJAMA                 │
# │ 98  │ 7520871001  │ PLACA DE SOM           │
# │ 103 │ 7627068421  │ PLACA DE VÍDEO         │
# │ 68  │ 1129682245  │ PLACA MÃE              │
# │ 110 │ 10506555482 │ ROTEADOR WIFI          │
# │ 100 │ 7537275412  │ SSD                    │
# │ 67  │ 1129682244  │ STARCHEF               │
# │ 106 │ 10448236085 │ STREAMER               │
# │ 66  │ 1129682243  │ SUPORTE PARA HEADSET   │
# │ 108 │ 10458435644 │ SUPORTE PARA MICROFONE │
# │ 92  │ 1515075769  │ SUPORTE PARA NOTEBOOK  │
# │ 95  │ 6759916663  │ SWITCH                 │
# │ 97  │ 6763892705  │ TECLADO DIY            │
# │ 64  │ 1129682241  │ TECLADO MECANICO       │
# │ 62  │ 1129682239  │ TECLADO MEMBRANA       │
# │ 63  │ 1129682240  │ TECLADO OPTICO         │
# │ 59  │ 1129682236  │ WATER COOLER           │
# │ 58  │ 1129682235  │ WEBCAM                 │
# └─────┴─────────────┴────────────────────────┘
# Total product families: 58
# [{'id': 115, 'codigo': 0, 'nome_familia': '', 'sample_products': [{'id': 4571, 'nome': 'MAQUINA RHEA XS E/3', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4500, 'nome': 'VOLVO/FH 420 4X2T PLACA QHA8A34 2014/2014', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4531, 'nome': 'Fonte de energia para carga direta para coletores Bluebird EF400, EF500 e Tablet RT100', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4532, 'nome': 'Capa Nacional de Protecao para Coletor BM180 BLUEBIRD com bateria padrao (Com alca de ombro) - BR', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4533, 'nome': 'Cabo Micro USB', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4590, 'nome': 'FILL AIR ROCKET TOP ASSY - 220 VAC', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4596, 'nome': 'TECLADO MECANICO RAHU RGB SWITCH AZUL (K567 RGB) - REDRAGON', 'descricao_detalhada': None, 'ean': '6950376750747', 'marca': ''}, {'id': 4705, 'nome': 'GABINETE GAMER REDRAGON SIDESWIPE GC-601 RGB', 'descricao_detalhada': None, 'ean': '2000000079189', 'marca': ''}, {'id': 4621, 'nome': 'Cooler para Processador DeepCool Gammaxx 400 V2, Red, 120mm, Intel-AMD, DP-MCH4-GMX400V2-RD', 'descricao_detalhada': None, 'ean': '', 'marca': ''}, {'id': 4622, 'nome': 'Memoria DDR4 Geil Orion RGB, Edicao AMD, 8GB, 3000MHz, Red, GAOSR48GB3000C16ASC', 'descricao_detalhada': None, 'ean': '', 'marca': ''}]}, {'id': 65, 'codigo': 1129682242, 'nome_familia': 'ACESSÓRIOS GABINETE', 'sample_products': [{'id': 3862, 'nome': 'SUPORTE PARA GH-01', 'descricao_detalhada': None, 'ean': '6933412796138', 'marca': 'DEEPCOOL'}, {'id': 3863, 'nome': 'SUPORTE PARA PLACA GH-01 RGB', 'descricao_detalhada': None, 'ean': '6933412796152', 'marca': 'DEEPCOOL'}, {'id': 3885, 'nome': 'ADAPTADOR O11 DYNAMIC/AIR VGA RISER CARD 200MM', 'descricao_detalhada': None, 'ean': '4718466008701', 'marca': 'LIAN LI'}, {'id': 3886, 'nome': 'ADAPTADOR LANCOOL II-4X PARA USB', 'descricao_detalhada': None, 'ean': '4718466009258', 'marca': 'LIAN LI'}, {'id': 3887, 'nome': 'ADAPTADOR LANCOOL II-3X PARA HD E SSD', 'descricao_detalhada': None, 'ean': '4718466009241', 'marca': 'LIAN LI'}, {'id': 3889, 'nome': 'CABO RGB 2X24 PINOS/5X8 PINOS AH-2PCCA-01', 'descricao_detalhada': None, 'ean': '5060301694709', 'marca': 'NZXT'}, {'id': 3982, 'nome': 'CONVERSOR RGB 5V PARA 12V', 'descricao_detalhada': None, 'ean': '6933412796114', 'marca': 'DEEPCOOL'}, {'id': 3983, 'nome': 'HUB PARA 4 FANS FH-04 BLACK', 'descricao_detalhada': None, 'ean': '6933412795995', 'marca': 'DEEPCOOL'}, {'id': 3984, 'nome': 'HUB PARA 10 FANS FH-10 BLACK', 'descricao_detalhada': None, 'ean': '', 'marca': 'DEEPCOOL'}, {'id': 4090, 'nome': 'FITA LED RGB 300X15X8MM AH-2UGKK-A1', 'descricao_detalhada': None, 'ean': '5060301694327', 'marca': 'NZXT'}]}, {'id': 113, 'codigo': 10546186400, 'nome_familia': 'ACESSÓRIOS OFFICE', 'sample_products': [{'id': 7400, 'nome': 'APRESENTADOR WIRELLES KEYTIME MATEPRO', 'descricao_detalhada': None, 'ean': '7898972678722', 'marca': 'KEYTIME'}, {'id': 7401, 'nome': 'APRESENTADOR WIRELLES KEYTIME POINT MASTER', 'descricao_detalhada': None, 'ean': '7898972678777', 'marca': 'KEYTIME'}]}, {'id': 109, 'codigo': 10506555149, 'nome_familia': 'ADAPTADOR USB WIFI', 'sample_products': [{'id': 7242, 'nome': 'ADAPTADOR WIRELLESS DUAL BAND USB CUDY AC 650 MODELO WU650', 'descricao_detalhada': None, 'ean': '6971690790851', 'marca': 'CUDY'}, {'id': 7243, 'nome': 'ADAPTADOR WIRELLESS DUAL BAND USB CUDY AC 1300 MODELO WU1300S', 'descricao_detalhada': None, 'ean': '6971690791186', 'marca': 'CUDY'}, {'id': 7244, 'nome': 'ADAPTADOR WIRELLESS DUAL BAND HIGH GAIN USB CUDY AC 1300 MODELO WU1400', 'descricao_detalhada': None, 'ean': '6971690791230', 'marca': 'CUDY'}]}, {'id': 81, 'codigo': 1129682258, 'nome_familia': 'AIR COOLER', 'sample_products': [{'id': 4143, 'nome': 'COOLER REDRAGON REAVER CC-1011 LED VERMELHO', 'descricao_detalhada': None, 'ean': '6950376778123', 'marca': 'REDRAGON ...

# %%
product_families
# Out:
# [{'id': 115,
#   'codigo': 0,
#   'nome_familia': '',
#   'sample_products': [{'id': 4571,
#     'nome': 'MAQUINA RHEA XS E/3',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4500,
#     'nome': 'VOLVO/FH 420 4X2T PLACA QHA8A34 2014/2014',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4531,
#     'nome': 'Fonte de energia para carga direta para coletores Bluebird EF400, EF500 e Tablet RT100',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4532,
#     'nome': 'Capa Nacional de Protecao para Coletor BM180 BLUEBIRD com bateria padrao (Com alca de ombro) - BR',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4533,
#     'nome': 'Cabo Micro USB',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4590,
#     'nome': 'FILL AIR ROCKET TOP ASSY - 220 VAC',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4596,
#     'nome': 'TECLADO MECANICO RAHU RGB SWITCH AZUL (K567 RGB) - REDRAGON',
#     'descricao_detalhada': None,
#     'ean': '6950376750747',
#     'marca': ''},
#    {'id': 4705,
#     'nome': 'GABINETE GAMER REDRAGON SIDESWIPE GC-601 RGB',
#     'descricao_detalhada': None,
#     'ean': '2000000079189',
#     'marca': ''},
#    {'id': 4621,
#     'nome': 'Cooler para Processador DeepCool Gammaxx 400 V2, Red, 120mm, Intel-AMD, DP-MCH4-GMX400V2-RD',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 4622,
#     'nome': 'Memoria DDR4 Geil Orion RGB, Edicao AMD, 8GB, 3000MHz, Red, GAOSR48GB3000C16ASC',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''}]},
#  {'id': 65,
#   'codigo': 1129682242,
#   'nome_familia': 'ACESSÓRIOS GABINETE',
#   'sample_products': [{'id': 3862,
#     'nome': 'SUPORTE PARA GH-01',
#     'descricao_detalhada': None,
#     'ean': '6933412796138',
#     'marca': 'DEEPCOOL'},
#    {'id': 3863,
#     'nome': 'SUPORTE PARA PLACA GH-01 RGB',
#     'descricao_detalhada': None,
#     'ean': '6933412796152',
#     'marca': 'DEEPCOOL'},
#    {'id': 3885,
#     'nome': 'ADAPTADOR O11 DYNAMIC/AIR VGA RISER CARD 200MM',
#     'descricao_detalhada': None,
#     'ean': '4718466008701',
#     'marca': 'LIAN LI'},
#    {'id': 3886,
#     'nome': 'ADAPTADOR LANCOOL II-4X PARA USB',
#     'descricao_detalhada': None,
#     'ean': '4718466009258',
#     'marca': 'LIAN LI'},
#    {'id': 3887,
#     'nome': 'ADAPTADOR LANCOOL II-3X PARA HD E SSD',
#     'descricao_detalhada': None,
#     'ean': '4718466009241',
#     'marca': 'LIAN LI'},
#    {'id': 3889,
#     'nome': 'CABO RGB 2X24 PINOS/5X8 PINOS AH-2PCCA-01',
#     'descricao_detalhada': None,
#     'ean': '5060301694709',
#     'marca': 'NZXT'},
#    {'id': 3982,
#     'nome': 'CONVERSOR RGB 5V PARA 12V',
#     'descricao_detalhada': None,
#     'ean': '6933412796114',
#     'marca': 'DEEPCOOL'},
#    {'id': 3983,
#     'nome': 'HUB PARA 4 FANS FH-04 BLACK',
#     'descricao_detalhada': None,
#     'ean': '6933412795995',
#     'marca': 'DEEPCOOL'},
#    {'id': 3984,
#     'nome': 'HUB PARA 10 FANS FH-10 BLACK',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'DEEPCOOL'},
#    {'id': 4090,
#     'nome': 'FITA LED RGB 300X15X8MM AH-2UGKK-A1',
#     'descricao_detalhada': None,
#     'ean': '5060301694327',
#     'marca': 'NZXT'}]},
#  {'id': 113,
#   'codigo': 10546186400,
#   'nome_familia': 'ACESSÓRIOS OFFICE',
#   'sample_products': [{'id': 7400,
#     'nome': 'APRESENTADOR WIRELLES KEYTIME MATEPRO',
#     'descricao_detalhada': None,
#     'ean': '7898972678722',
#     'marca': 'KEYTIME'},
#    {'id': 7401,
#     'nome': 'APRESENTADOR WIRELLES KEYTIME POINT MASTER',
#     'descricao_detalhada': None,
#     'ean': '7898972678777',
#     'marca': 'KEYTIME'}]},
#  {'id': 109,
#   'codigo': 10506555149,
#   'nome_familia': 'ADAPTADOR USB WIFI',
#   'sample_products': [{'id': 7242,
#     'nome': 'ADAPTADOR WIRELLESS DUAL BAND USB CUDY AC 650 MODELO WU650',
#     'descricao_detalhada': None,
#     'ean': '6971690790851',
#     'marca': 'CUDY'},
#    {'id': 7243,
#     'nome': 'ADAPTADOR WIRELLESS DUAL BAND USB CUDY AC 1300 MODELO WU1300S',
#     'descricao_detalhada': None,
#     'ean': '6971690791186',
#     'marca': 'CUDY'},
#    {'id': 7244,
#     'nome': 'ADAPTADOR WIRELLESS DUAL BAND HIGH GAIN USB CUDY AC 1300 MODELO WU1400',
#     'descricao_detalhada': None,
#     'ean': '6971690791230',
#     'marca': 'CUDY'}]},
#  {'id': 81,
#   'codigo': 1129682258,
#   'nome_familia': 'AIR COOLER',
#   'sample_products': [{'id': 4143,
#     'nome': 'COOLER REDRAGON REAVER CC-1011 LED VERMELHO',
#     'descricao_detalhada': None,
#     'ean': '6950376778123',
#     'marca': 'REDRAGON'},
#    {'id': 4149,
#     'nome': 'COOLER PARA VGA KRAKEN G12 BRANCO',
#     'descricao_detalhada': None,
#     'ean': '5060301693610',
#     'marca': 'NZXT'},
#    {'id': 4150,
#     'nome': 'COOLER PARA VGA KRAKEN G12 PRETO',
#     'descricao_detalhada': None,
#     'ean': '5060301693627',
#     'marca': 'NZXT'},
#    {'id': 4151,
#     'nome': 'COOLER PARA VGA KRAKEN G10 BRANCO',
#     'descricao_detalhada': None,
#     'ean': '5060301691005',
#     'marca': 'NZXT'},
#    {'id': 4176,
#     'nome': 'COOLER V95',
#     'descricao_detalhada': None,
#     'ean': '6933412715115',
#     'marca': 'DEEPCOOL'},
#    {'id': 4177,
#     'nome': 'COOLER SHURIKEN 2 LOW PROFILE',
#     'descricao_detalhada': None,
#     'ean': '4571225057187',
#     'marca': 'SCYTHE'},
#    {'id': 4178,
#     'nome': 'COOLER MUGEN 5 A-RGB PLUS',
#     'descricao_detalhada': None,
#     'ean': '4571225057606',
#     'marca': 'SCYTHE'},
#    {'id': 4179,
#     'nome': 'COOLER MUGEN 5 TUF',
#     'descricao_detalhada': None,
#     'ean': '4571225057088',
#     'marca': 'SCYTHE'},
#    {'id': 4180,
#     'nome': 'COOLER KOTETSU MARK II',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'SCYTHE'},
#    {'id': 4182,
#     'nome': 'COOLER CHOTEN',
#     'descricao_detalhada': None,
#     'ean': '4571225056524',
#     'marca': 'SCYTHE'}]},
#  {'id': 85,
#   'codigo': 1129682262,
#   'nome_familia': 'APOIO PARA TECLADO',
#   'sample_products': [{'id': 4175,
#     'nome': 'APOIO PARA TECLADO 430X80X23MM',
#     'descricao_detalhada': None,
#     'ean': '6950376782496',
#     'marca': 'REDRAGON'},
#    {'id': 4221,
#     'nome': 'APOIO PARA TECLADO 430X80X23MM.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4560,
#     'nome': 'APOIO PARA TECLADO GAMER INFERNAL DRAGON',
#     'descricao_detalhada': None,
#     'ean': '6950376781598',
#     'marca': 'REDRAGON'},
#    {'id': 5261,
#     'nome': 'APOIO PARA TECLADO GAMER METEOR E PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376707291',
#     'marca': 'REDRAGON'},
#    {'id': 5263,
#     'nome': 'APOIO PARA TECLADO GAMER METEOR L PRETO 435X73X20MM',
#     'descricao_detalhada': None,
#     'ean': '6950376704849',
#     'marca': 'REDRAGON'},
#    {'id': 5264,
#     'nome': 'APOIO PARA TECLADO GAMER METEOR S PRETO 289X73X20MM',
#     'descricao_detalhada': None,
#     'ean': '6950376704825',
#     'marca': 'REDRAGON'},
#    {'id': 5265,
#     'nome': 'APOIO PARA TECLADO GAMER METEOR M PRETO 359X73X20MM',
#     'descricao_detalhada': None,
#     'ean': '6950376704832',
#     'marca': 'REDRAGON'},
#    {'id': 5696,
#     'nome': 'Cópia de APOIO PARA TECLADO GAMER METEOR L PRETO 435X73X20MM em 08/02/2023 às 14:14:20',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 5697,
#     'nome': 'APOIO PARA TECLADO ONE PIECE WANO COUNTRY WRIST REST 98 SIZE',
#     'descricao_detalhada': None,
#     'ean': '6925758614405',
#     'marca': 'AKKO'},
#    {'id': 5698,
#     'nome': 'APOIO PARA TECLADO ONE PIECE WANO COUNTRY WRIST REST 108 SIZE',
#     'descricao_detalhada': None,
#     'ean': '6925758609838',
#     'marca': 'AKKO'}]},
#  {'id': 104,
#   'codigo': 7630787841,
#   'nome_familia': 'AUTO CARE',
#   'sample_products': [{'id': 6001,
#     'nome': 'CERA NANO IMPERMEABILIZANTE 4 EM 1 REDRAGON AUTO CARE SHINEX',
#     'descricao_detalhada': None,
#     'ean': '7898972678180',
#     'marca': 'REDRAGON'},
#    {'id': 6002,
#     'nome': 'REVITALIZADOR DE PLÁSTICOS + ESPONJA APLICADORA REDRAGON AUTO CARE GT-SHINE 20ml',
#     'descricao_detalhada': None,
#     'ean': '7899870102241',
#     'marca': 'REDRAGON'},
#    {'id': 6003,
#     'nome': 'REVITALIZADOR DE PLÁSTICOS + ESPONJA APLICADORA REDRAGON AUTO CARE GT-SHINE 50ml',
#     'descricao_detalhada': None,
#     'ean': '7899870100735',
#     'marca': 'REDRAGON'},
#    {'id': 6004,
#     'nome': 'LIMPADOR DESINCRUSTANTE 4 EM 1 REDRAGON AUTO CARE FORTEX 1L',
#     'descricao_detalhada': None,
#     'ean': '7898972678142',
#     'marca': 'REDRAGON'},
#    {'id': 6005,
#     'nome': 'REMOVEDOR DE FERRUGEM REDRAGON AUTO CARE IGNITE 500ml',
#     'descricao_detalhada': None,
#     'ean': '7898972678128',
#     'marca': 'REDRAGON'},
#    {'id': 6013,
#     'nome': 'LIMPEZA A SECO REDRAGON AUTO CARE FURY 500 ML',
#     'descricao_detalhada': None,
#     'ean': '7898972678166',
#     'marca': 'REDRAGON'},
#    {'id': 6014,
#     'nome': 'LIMPADOR INTERNO REDRAGON AUTO CARE TITAN 500 ML',
#     'descricao_detalhada': None,
#     'ean': '7898972678173',
#     'marca': 'REDRAGON'},
#    {'id': 6015,
#     'nome': 'REVITALIZADOR DE PNEUS REDRAGON AUTO CARE MIDNIGHT 500 ML',
#     'descricao_detalhada': None,
#     'ean': '7898972678135',
#     'marca': 'REDRAGON'},
#    {'id': 6016,
#     'nome': 'SHAMPOO NEUTRO AUTOMOTIVO REDRAGON AUTO CARE RADIANT 1 L',
#     'descricao_detalhada': None,
#     'ean': '7898972678241',
#     'marca': 'REDRAGON'},
#    {'id': 6017,
#     'nome': 'LIMPA PNEUS E BORRACHAS REDRAGON AUTO CARE ERASER 500 ML',
#     'descricao_detalhada': None,
#     'ean': '7898972678197',
#     'marca': 'REDRAGON'}]},
#  {'id': 93,
#   'codigo': 1643432804,
#   'nome_familia': 'BERMUDA',
#   'sample_products': [{'id': 4887,
#     'nome': 'BERMUDA MOLETOM - PRETO - 2644 (G)',
#     'descricao_detalhada': None,
#     'ean': '0788115638683',
#     'marca': 'REDRAGON'},
#    {'id': 4891,
#     'nome': 'BERMUDA MOLETOM - PRETO - 2644 (XG)',
#     'descricao_detalhada': None,
#     'ean': '0788115638720',
#     'marca': 'REDRAGON'},
#    {'id': 4892,
#     'nome': 'BERMUDA MOLETOM - PRETO - 2644 (XGG)',
#     'descricao_detalhada': None,
#     'ean': '0788115638737',
#     'marca': 'REDRAGON'},
#    {'id': 4894,
#     'nome': 'BERMUDA RECORTE DUPLO COM BOLSO TRASEIRO - PRETO - 2644 (GG)',
#     'descricao_detalhada': None,
#     'ean': '0788115638751',
#     'marca': 'REDRAGON'},
#    {'id': 4895,
#     'nome': 'BERMUDA RECORTE DUPLO COM BOLSO TRASEIRO - PRETO - 2644 (M)',
#     'descricao_detalhada': None,
#     'ean': '0788115638768',
#     'marca': 'REDRAGON'},
#    {'id': 4896,
#     'nome': 'BERMUDA RECORTE DUPLO COM BOLSO TRASEIRO - PRETO - 2644 (P)',
#     'descricao_detalhada': None,
#     'ean': '0788115638775',
#     'marca': 'REDRAGON'},
#    {'id': 4897,
#     'nome': 'BERMUDA RECORTE DUPLO COM BOLSO TRASEIRO - PRETO - 2644 (XG)',
#     'descricao_detalhada': None,
#     'ean': '0788115638782',
#     'marca': 'REDRAGON'},
#    {'id': 4898,
#     'nome': 'BERMUDA RECORTE DUPLO COM BOLSO TRASEIRO - PRETO - 2644 (XGG)',
#     'descricao_detalhada': None,
#     'ean': '0788115638799',
#     'marca': 'REDRAGON'},
#    {'id': 4890,
#     'nome': 'BERMUDA MOLETOM - PRETO - 2644 (P)',
#     'descricao_detalhada': None,
#     'ean': '0788115638713',
#     'marca': 'REDRAGON'},
#    {'id': 4889,
#     'nome': 'BERMUDA MOLETOM - PRETO - 2644 (M)',
#     'descricao_detalhada': None,
#     'ean': '0788115638706',
#     'marca': 'REDRAGON'}]},
#  {'id': 84,
#   'codigo': 1129682261,
#   'nome_familia': 'BOARD GAMES',
#   'sample_products': [{'id': 4173,
#     'nome': 'JOGO DE TABULEIRO TIRANOS DE UNDERDARK',
#     'descricao_detalhada': None,
#     'ean': '7899834055491',
#     'marca': 'GALEFORCE9'}]},
#  {'id': 96,
#   'codigo': 6759916857,
#   'nome_familia': 'CABOS',
#   'sample_products': [{'id': 5187,
#     'nome': 'CABO PARA TECLADO ENROLADO MODELO PINK',
#     'descricao_detalhada': None,
#     'ean': '6925758615266',
#     'marca': 'AKKO'},
#    {'id': 5188,
#     'nome': 'CABO PARA TECLADO ENROLADO MODELO BLUE',
#     'descricao_detalhada': None,
#     'ean': '6925758615259',
#     'marca': 'AKKO'},
#    {'id': 5189,
#     'nome': 'CABO PARA TECLADO ENROLADO MODELO BLACK',
#     'descricao_detalhada': None,
#     'ean': '6925758615273',
#     'marca': 'AKKO'},
#    {'id': 5190,
#     'nome': 'CABO PARA TECLADO ENROLADO AVIATOR MODELO 9009',
#     'descricao_detalhada': None,
#     'ean': '6925758615921',
#     'marca': 'AKKO'},
#    {'id': 5191,
#     'nome': 'CABO PARA TECLADO ENROLADO AVIATOR MODELO MACAW',
#     'descricao_detalhada': None,
#     'ean': '6925758615945',
#     'marca': 'AKKO'},
#    {'id': 5192,
#     'nome': 'CABO PARA TECLADO ENROLADO AVIATOR MODELO LOS ANGELES',
#     'descricao_detalhada': None,
#     'ean': '6925758617840',
#     'marca': 'AKKO'},
#    {'id': 5193,
#     'nome': 'CABO PARA TECLADO ENROLADO AVIATOR MODELO BLACK AND PINK',
#     'descricao_detalhada': None,
#     'ean': '6925758615907',
#     'marca': 'AKKO'},
#    {'id': 5195,
#     'nome': 'CABO PARA TECLADO ENROLADO AVIATOR MODELO PRUNUS',
#     'descricao_detalhada': None,
#     'ean': '6925758617857',
#     'marca': 'AKKO'},
#    {'id': 5196,
#     'nome': 'CABO PARA TECLADO ENROLADO AVIATOR MODELO SAKURA',
#     'descricao_detalhada': None,
#     'ean': '6925758615938',
#     'marca': 'AKKO'},
#    {'id': 5588,
#     'nome': 'CABO PARA TECLADO ENROLADO USB-C PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376712073',
#     'marca': 'REDRAGON'}]},
#  {'id': 88,
#   'codigo': 1163533626,
#   'nome_familia': 'CADEIRA',
#   'sample_products': [{'id': 4443,
#     'nome': 'CADEIRA GAMER GD-ACHILLES P1LBR',
#     'descricao_detalhada': None,
#     'ean': '4712960131149',
#     'marca': 'GAMDIAS'},
#    {'id': 4445,
#     'nome': 'CADEIRA GD-ZELUS E1LB',
#     'descricao_detalhada': None,
#     'ean': '4712960133686',
#     'marca': 'GAMDIAS'},
#    {'id': 4456,
#     'nome': 'CADEIRA GAMER ASSASSIN PRETA',
#     'descricao_detalhada': None,
#     'ean': '6950376783905',
#     'marca': 'REDRAGON'},
#    {'id': 4457,
#     'nome': 'CADEIRA GAMER KING OF WAR PRETA',
#     'descricao_detalhada': None,
#     'ean': '6950376783912',
#     'marca': 'REDRAGON'},
#    {'id': 4517,
#     'nome': 'CADEIRA SL2000 PRETO E AZUL',
#     'descricao_detalhada': None,
#     'ean': '617724127601',
#     'marca': 'VERTAGEAR'},
#    {'id': 4630,
#     'nome': 'CADEIRA GAMER METIS PRETA/VERMELHA',
#     'descricao_detalhada': None,
#     'ean': '6950376774637',
#     'marca': 'REDRAGON'},
#    {'id': 4631,
#     'nome': 'CADEIRA GAMER METIS PRETA/CINZA',
#     'descricao_detalhada': None,
#     'ean': '6950376775214',
#     'marca': 'REDRAGON'},
#    {'id': 4632,
#     'nome': 'CADEIRA GAMER METIS PRETA',
#     'descricao_detalhada': None,
#     'ean': '6950376775092',
#     'marca': 'REDRAGON'},
#    {'id': 4673,
#     'nome': 'CADEIRA SL1000 PRETA E VERMELHA',
#     'descricao_detalhada': None,
#     'ean': '850008175121',
#     'marca': 'VERTAGEAR'},
#    {'id': 5372,
#     'nome': 'CADEIRA GAMER REDRAGON COEUS PRETO/AZUL C201-BB',
#     'descricao_detalhada': None,
#     'ean': '6950376783011',
#     'marca': 'REDRAGON'}]},
#  {'id': 83,
#   'codigo': 1129682260,
#   'nome_familia': 'CAIXA DE SOM',
#   'sample_products': [{'id': 4158,
#     'nome': 'CAIXA DE SOM GAMER RGB XTRIKE ME SK-501',
#     'descricao_detalhada': None,
#     'ean': '6932391919422',
#     'marca': 'XTRIKE ME'},
#    {'id': 4160,
#     'nome': 'CAIXA DE SOM GAMER SCORPION MARVO RAINBOW (SG-118)',
#     'descricao_detalhada': None,
#     'ean': '6932391920138',
#     'marca': 'MARVO'},
#    {'id': 4345,
#     'nome': 'CAIXA DE SOM MARVO SG-266 BT',
#     'descricao_detalhada': None,
#     'ean': '6932391920633',
#     'marca': 'MARVO'},
#    {'id': 4387,
#     'nome': 'ADAPTADOR CIRCE USB AUDIO.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4434,
#     'nome': 'CAIXA DE SOM GAMER ANVIL RGB..',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4449,
#     'nome': 'MARVO GAMER SCORPION MARVO RAINBOW (SG-265)',
#     'descricao_detalhada': None,
#     'ean': '6932391919712',
#     'marca': 'MARVO'},
#    {'id': 4451,
#     'nome': 'CAIXA DE SOM GAMER STENTOR.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4467,
#     'nome': 'CAIXA DE SOM MARVO SG-290',
#     'descricao_detalhada': None,
#     'ean': '6932391922262',
#     'marca': 'MARVO'},
#    {'id': 4526,
#     'nome': 'CAIXA DE SOM HP DHE-6002',
#     'descricao_detalhada': None,
#     'ean': '6972431710633',
#     'marca': 'HP'},
#    {'id': 4715,
#     'nome': 'CAIXA DE SOM GAMER AIR RGB',
#     'descricao_detalhada': None,
#     'ean': '6950376781451',
#     'marca': 'REDRAGON'}]},
#  {'id': 90,
#   'codigo': 1397365053,
#   'nome_familia': 'CAMISETA',
#   'sample_products': [{'id': 4720,
#     'nome': 'CAMISETA - BRANCO MD1 - 2380 (G)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4721,
#     'nome': 'CAMISETA - BRANCO MD1 - 2380 (GG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4722,
#     'nome': 'CAMISETA - BRANCO MD1 - 2380 (M)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4723,
#     'nome': 'CAMISETA - BRANCO MD1 - 2380 (P)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4724,
#     'nome': 'CAMISETA - BRANCO MD1 - 2380 (XG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4725,
#     'nome': 'CAMISETA - BRANCO MD1 - 2380 (XGG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4726,
#     'nome': 'CAMISETA - PRETO MD2 - 2380 (G)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4727,
#     'nome': 'CAMISETA - PRETO MD2 - 2380 (GG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4728,
#     'nome': 'CAMISETA - PRETO MD2 - 2380 (M)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4730,
#     'nome': 'CAMISETA - PRETO MD2 - 2380 (XG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'}]},
#  {'id': 91,
#   'codigo': 1397365071,
#   'nome_familia': 'CAMISOLA',
#   'sample_products': [{'id': 4763,
#     'nome': 'CAMISOLA - PRETO - 2380 (GG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4764,
#     'nome': 'CAMISOLA - PRETO - 2380 (M)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4765,
#     'nome': 'CAMISOLA - PRETO - 2380 (P)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4766,
#     'nome': 'CAMISOLA - PRETO - 2380 (XG)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4762,
#     'nome': 'CAMISOLA - PRETO - 2380 (G)',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'}]},
#  {'id': 82,
#   'codigo': 1129682259,
#   'nome_familia': 'CANETA DIGITAL',
#   'sample_products': [{'id': 4153,
#     'nome': 'CANETA PARA MESA DIGITALIZADORA P01',
#     'descricao_detalhada': None,
#     'ean': '0708402555851',
#     'marca': 'XP-PEN'},
#    {'id': 4154,
#     'nome': 'CANETA PARA MESA DIGITALIZADORA P05S',
#     'descricao_detalhada': None,
#     'ean': '7897473191921',
#     'marca': 'XP-PEN'},
#    {'id': 4155,
#     'nome': 'CANETA PARA MESA DIGITALIZADORA P05',
#     'descricao_detalhada': None,
#     'ean': '0761460827056',
#     'marca': 'XP-PEN'},
#    {'id': 4156,
#     'nome': 'ONTAS PARA CANETA PA2',
#     'descricao_detalhada': None,
#     'ean': '7897473191945',
#     'marca': 'XP-PEN'},
#    {'id': 4157,
#     'nome': 'PONTAS PARA CANETAS XP-PEN AC04_B',
#     'descricao_detalhada': None,
#     'ean': '7897473191938',
#     'marca': 'XP-PEN'},
#    {'id': 4217,
#     'nome': 'CANETA ESFEROGRAFICA XP-PEN AC99',
#     'descricao_detalhada': None,
#     'ean': '7897473191723',
#     'marca': 'XP-PEN'},
#    {'id': 4220,
#     'nome': 'PONTAS PARA CANETAS XP-PEN AC04_B.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'XP-PEN'},
#    {'id': 4301,
#     'nome': 'CANETA PARA MESA DIGITALIZADORA AD02',
#     'descricao_detalhada': None,
#     'ean': '7897473191716',
#     'marca': 'XP-PEN'}]},
#  {'id': 61,
#   'codigo': 1129682238,
#   'nome_familia': 'COMBO',
#   'sample_products': [{'id': 3785,
#     'nome': 'KIT GAMER TECLADO E MOUSE BRANCO S118W',
#     'descricao_detalhada': None,
#     'ean': '6950376778406',
#     'marca': 'REDRAGON'},
#    {'id': 3786,
#     'nome': 'KIT GAMER TECLADO E MOUSE S118',
#     'descricao_detalhada': None,
#     'ean': '6950376778390',
#     'marca': 'REDRAGON'},
#    {'id': 3789,
#     'nome': 'KIT TECLADO/MOUSE S108 LIGHT GREEN',
#     'descricao_detalhada': None,
#     'ean': '6950376775412',
#     'marca': 'REDRAGON'},
#    {'id': 3790,
#     'nome': 'KIT GAMER REDRAGON TECLADO E MOUSE DARK GREEN',
#     'descricao_detalhada': None,
#     'ean': '6950376775405',
#     'marca': 'REDRAGON'},
#    {'id': 3791,
#     'nome': 'KIT TECLADO E MOUSE VAJRA',
#     'descricao_detalhada': None,
#     'ean': '6950376783189',
#     'marca': 'REDRAGON'},
#    {'id': 3792,
#     'nome': 'KIT TECLADO E MOUSE GAMING ESSENTIALS S101-1',
#     'descricao_detalhada': None,
#     'ean': '6950376783196',
#     'marca': 'REDRAGON'},
#    {'id': 3793,
#     'nome': 'KIT TECLADO E MOUSE XTRIKE ME MK-503KIT',
#     'descricao_detalhada': None,
#     'ean': '6932391922088',
#     'marca': 'XTRIKE ME'},
#    {'id': 3795,
#     'nome': 'KIT GAMER TECLADO/MOUSE/MOUSEPAD/HEADSET KWG ARIES M1',
#     'descricao_detalhada': None,
#     'ean': '4712960134195',
#     'marca': 'KWG'},
#    {'id': 3796,
#     'nome': 'KIT TECLADO E MOUSE GAMER MULTI COLOR KWG ARIES E1',
#     'descricao_detalhada': None,
#     'ean': '4712960134201',
#     'marca': 'KWG'},
#    {'id': 3916,
#     'nome': 'KIT GAMER MOUSE E MOUSEPAD',
#     'descricao_detalhada': None,
#     'ean': '6950376782267',
#     'marca': 'REDRAGON'}]},
#  {'id': 86,
#   'codigo': 1129682263,
#   'nome_familia': 'CONSOLE',
#   'sample_products': [{'id': 4207,
#     'nome': 'ADAPTADOR DE TECLADO E MOUSE',
#     'descricao_detalhada': None,
#     'ean': '6950376774682',
#     'marca': 'REDRAGON'},
#    {'id': 4206,
#     'nome': 'ADAPTADOR DE TECLADO E MOUSE  VULCAN GA-250.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 5012,
#     'nome': 'Apagar Esse Aqui.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''}]},
#  {'id': 99,
#   'codigo': 7520871400,
#   'nome_familia': 'DAC',
#   'sample_products': [{'id': 6550,
#     'nome': 'ADAPTADOR CIRCE USB AUDIO',
#     'descricao_detalhada': None,
#     'ean': '6950376774392',
#     'marca': 'REDRAGON'}]},
#  {'id': 112,
#   'codigo': 10506555811,
#   'nome_familia': 'DOCK STATION',
#   'sample_products': [{'id': 7248,
#     'nome': 'DOCK STATION CUDY DUAL 4K 10 GBPS USB-C MODELO CS700',
#     'descricao_detalhada': None,
#     'ean': '6971690793098',
#     'marca': 'CUDY'}]},
#  {'id': 70,
#   'codigo': 1129682247,
#   'nome_familia': 'FAN',
#   'sample_products': [{'id': 3882,
#     'nome': 'CAPA PARA FAN AER P120 BRANCA',
#     'descricao_detalhada': None,
#     'ean': '5060301693375',
#     'marca': 'NZXT'},
#    {'id': 3884,
#     'nome': 'CAPA PARA FAN AER P120 VERMELHA',
#     'descricao_detalhada': None,
#     'ean': '5060301693351',
#     'marca': 'NZXT'},
#    {'id': 4092,
#     'nome': 'KIT 3FANS ALSEYE RGB X12 ELECTROPLATE SILVER',
#     'descricao_detalhada': None,
#     'ean': '4897059874487',
#     'marca': 'ALSEYE'},
#    {'id': 4093,
#     'nome': 'KIT 3FANS ALSEYE RGB X12 ELECTROPLATE ROSE GOLD',
#     'descricao_detalhada': None,
#     'ean': '4897059874470',
#     'marca': 'ALSEYE'},
#    {'id': 4094,
#     'nome': 'KIT 3FANS ALSEYE XTREME X12 ARGB GREY',
#     'descricao_detalhada': None,
#     'ean': '4897059872469',
#     'marca': 'ALSEYE'},
#    {'id': 4095,
#     'nome': 'KIT 3FANS ALSEYE RGB X12 ELECTROPLATE GOLD',
#     'descricao_detalhada': None,
#     'ean': '4897059874463',
#     'marca': 'ALSEYE'},
#    {'id': 4096,
#     'nome': 'FAN ALSEYE X12 A-RGB WHITE',
#     'descricao_detalhada': None,
#     'ean': '4897059872537',
#     'marca': 'ALSEYE'},
#    {'id': 4097,
#     'nome': 'FAN ALSEYE X12 A-RGB GREY',
#     'descricao_detalhada': None,
#     'ean': '4897059872520',
#     'marca': 'ALSEYE'},
#    {'id': 4098,
#     'nome': 'FAN 120X25MM WIND LIGHT RAINBOW RGB',
#     'descricao_detalhada': None,
#     'ean': '4897059871332',
#     'marca': 'ALSEYE'},
#    {'id': 4099,
#     'nome': 'KIT GAMER UNI FAN RGB BRANCO COM 3 FANS',
#     'descricao_detalhada': None,
#     'ean': '4718466009531',
#     'marca': 'LIAN LI'}]},
#  {'id': 80,
#   'codigo': 1129682257,
#   'nome_familia': 'FONTE',
#   'sample_products': [{'id': 4083,
#     'nome': 'FONTE T-DAGGER T-TPS202 600W BIVOLT SEM CABO',
#     'descricao_detalhada': None,
#     'ean': '6950376781079',
#     'marca': 'T-DAGGER'},
#    {'id': 4085,
#     'nome': 'FONTE ONEPOWER DE 500 WATTS 110/220V SEM CABO DE FORÇA',
#     'descricao_detalhada': None,
#     'ean': '7898573240625',
#     'marca': 'ONEPOWER'},
#    {'id': 4086,
#     'nome': 'FONTE GAMER 700 WATTS FULL MODULAR 80 PLUS BRONZE',
#     'descricao_detalhada': None,
#     'ean': '6950376778291',
#     'marca': 'REDRAGON'},
#    {'id': 4087,
#     'nome': 'FONTE GAMER 600 WATTS FULL MODULAR 80 PLUS BRONZE',
#     'descricao_detalhada': None,
#     'ean': '6950376778284',
#     'marca': 'REDRAGON'},
#    {'id': 4088,
#     'nome': 'FONTE GAMER 600 WATTS 80 PLUS BRONZE',
#     'descricao_detalhada': None,
#     'ean': '6950376778277',
#     'marca': 'REDRAGON'},
#    {'id': 4089,
#     'nome': 'FONTE GAMER 500 WATTS 80 PLUS BRONZE',
#     'descricao_detalhada': None,
#     'ean': '6950376778260',
#     'marca': 'REDRAGON'},
#    {'id': 4239,
#     'nome': 'FONTE GAMDIAS KRATOS E1 500 WATTS',
#     'descricao_detalhada': None,
#     'ean': '4712960133761',
#     'marca': 'GAMDIAS'},
#    {'id': 4285,
#     'nome': 'FONTE GAMDIAS KRATOS M1 750 WATTS 80 PLUS',
#     'descricao_detalhada': None,
#     'ean': '4712960134003',
#     'marca': 'GAMDIAS'},
#    {'id': 4286,
#     'nome': 'FONTE GAMDIAS KRATOS M1 600 WATTS 80 PLUS',
#     'descricao_detalhada': None,
#     'ean': '4712960133808',
#     'marca': 'GAMDIAS'},
#    {'id': 4359,
#     'nome': 'FONTE GAMER 80 PLUS 600 WATTS',
#     'descricao_detalhada': None,
#     'ean': '6933412798705',
#     'marca': 'DEEPCOOL'}]},
#  {'id': 79,
#   'codigo': 1129682256,
#   'nome_familia': 'GABINETE',
#   'sample_products': [{'id': 4017,
#     'nome': 'GABINETE TU150X PRETO',
#     'descricao_detalhada': None,
#     'ean': '4718466009081',
#     'marca': 'LIAN LI'},
#    {'id': 4018,
#     'nome': 'GABINETE GAMER TU150 WX PRETO',
#     'descricao_detalhada': None,
#     'ean': '4718466009067',
#     'marca': 'LIAN LI'},
#    {'id': 4019,
#     'nome': 'GABINETE GAMER TU150 WA PRATA',
#     'descricao_detalhada': None,
#     'ean': '4718466009074',
#     'marca': 'LIAN LI'},
#    {'id': 4020,
#     'nome': 'GABINETE TU150A PRATA',
#     'descricao_detalhada': None,
#     'ean': '4718466009128',
#     'marca': 'LIAN LI'},
#    {'id': 4021,
#     'nome': 'GABINETE TALOSP1A PRETO',
#     'descricao_detalhada': None,
#     'ean': '4712960133747',
#     'marca': 'GAMDIAS'},
#    {'id': 4022,
#     'nome': 'GABINETE TALOS M1B PRETO',
#     'descricao_detalhada': None,
#     'ean': '4712960134737',
#     'marca': 'GAMDIAS'},
#    {'id': 4023,
#     'nome': 'GABINETE TALOS M1 LITE PRETO',
#     'descricao_detalhada': None,
#     'ean': '4712960134676',
#     'marca': 'GAMDIAS'},
#    {'id': 4024,
#     'nome': 'GABINETE GAMER TALOS E1 PRETO SEM FAN',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'GAMDIAS'},
#    {'id': 4029,
#     'nome': 'GABINETE GAMER CL500 CN',
#     'descricao_detalhada': None,
#     'ean': '6933412714484',
#     'marca': 'DEEPCOOL'},
#    {'id': 4030,
#     'nome': 'GABINETE GAMER  DYNAMIC O11 DXL-X PRETO',
#     'descricao_detalhada': None,
#     'ean': '4718466009043',
#     'marca': 'LIAN LI'}]},
#  {'id': 78,
#   'codigo': 1129682255,
#   'nome_familia': 'HEADSET',
#   'sample_products': [{'id': 3985,
#     'nome': 'HEADSET GAMER T-DAGGER EIGER',
#     'descricao_detalhada': None,
#     'ean': '6950376779175',
#     'marca': 'T-DAGGER'},
#    {'id': 3986,
#     'nome': 'HEADSET GAMER ATLAS PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376783868',
#     'marca': 'T-DAGGER'},
#    {'id': 3987,
#     'nome': 'HEADSET GAMER T-DAGGER MCKINLEY',
#     'descricao_detalhada': None,
#     'ean': '6950376779168',
#     'marca': 'T-DAGGER'},
#    {'id': 3988,
#     'nome': 'HEADSET COM FIO XTRIKE ME HP-310',
#     'descricao_detalhada': None,
#     'ean': '6932391920671',
#     'marca': 'XTRIKE ME'},
#    {'id': 3989,
#     'nome': 'HEADSET GAMER XTRIKE ME  HP-307',
#     'descricao_detalhada': None,
#     'ean': '6932391917831',
#     'marca': 'XTRIKE ME'},
#    {'id': 3990,
#     'nome': 'HEADSET GAMER SCORPION MARVO COM FIO MARVO HG9049',
#     'descricao_detalhada': None,
#     'ean': '6932391919521',
#     'marca': 'MARVO'},
#    {'id': 3991,
#     'nome': 'HEADSET GAMER SCORPION MARVO RAINBOW HG8929',
#     'descricao_detalhada': None,
#     'ean': '6932391919545',
#     'marca': 'MARVO'},
#    {'id': 3992,
#     'nome': 'HEADSET GAMER SCORPION MARVO LED VERMELHO COM FIO HG8928',
#     'descricao_detalhada': None,
#     'ean': '6932391917565',
#     'marca': 'MARVO'},
#    {'id': 3993,
#     'nome': 'HEADSET GAMER SCORPION MARVO RAINBOW HG8901',
#     'descricao_detalhada': None,
#     'ean': '6932391921227',
#     'marca': 'MARVO'},
#    {'id': 3994,
#     'nome': 'HEADSET HEPHAESTUS E1',
#     'descricao_detalhada': None,
#     'ean': '4712960132245',
#     'marca': 'GAMDIAS'}]},
#  {'id': 111,
#   'codigo': 10506555697,
#   'nome_familia': 'HUB/SWITCH',
#   'sample_products': [{'id': 7241,
#     'nome': 'HUB USB-C 6 IN 1 CUDY MODELO UH500',
#     'descricao_detalhada': None,
#     'ean': '6971690793609',
#     'marca': 'CUDY'},
#    {'id': 7245,
#     'nome': 'SWITCH CUDY 5 PORTA PRETO MODELO GS105D',
#     'descricao_detalhada': None,
#     'ean': '6971690790097',
#     'marca': 'CUDY'},
#    {'id': 7246,
#     'nome': 'SWITCH CUDY 8 PORTA PRETO MODELO GS108D',
#     'descricao_detalhada': None,
#     'ean': '6971690790103',
#     'marca': 'CUDY'},
#    {'id': 7384,
#     'nome': 'ADAPTADOR USB 4 EM 1 KEYTIME SYNCZONE KYT00034',
#     'descricao_detalhada': None,
#     'ean': '7898762150018',
#     'marca': 'KEYTIME'},
#    {'id': 7386,
#     'nome': 'ADAPTADOR USB 5 EM 1 KEYTIME HUB STATION KYT00033',
#     'descricao_detalhada': None,
#     'ean': '7898762150001',
#     'marca': 'KEYTIME'},
#    {'id': 7387,
#     'nome': 'ADAPTADOR USB 7 EM 1 KEYTIME DATA PORT KYT00036',
#     'descricao_detalhada': None,
#     'ean': '7898762150032',
#     'marca': 'KEYTIME'},
#    {'id': 7426,
#     'nome': 'ADAPTADOR L-WIRELESS PARA CONTROLE DE RGB BRANCO RF-T-W WHITE',
#     'descricao_detalhada': None,
#     'ean': '4718466016683',
#     'marca': 'LIAN LI'},
#    {'id': 7385,
#     'nome': 'ADAPTADOR USB 5 EM 1 KEYTIME LINK POINT KYT00035',
#     'descricao_detalhada': None,
#     'ean': '7898762150025',
#     'marca': 'KEYTIME'},
#    {'id': 7427,
#     'nome': 'ADAPTADOR L-WIRELESS PARA CONTROLE DE RGB PRETO RF-T-B BLACK',
#     'descricao_detalhada': None,
#     'ean': '4718466016676',
#     'marca': 'LIAN LI'}]},
#  {'id': 102,
#   'codigo': 7561382514,
#   'nome_familia': 'ILUMINAÇÃO',
#   'sample_products': [{'id': 5605,
#     'nome': 'NANOLEAF SHAPES HEXAGONS BRANCO COM 7 PECAS',
#     'descricao_detalhada': None,
#     'ean': '840102702590',
#     'marca': 'NANOLEAF'},
#    {'id': 5606,
#     'nome': 'NANOLEAF SHAPES HEXAGON APENAS PAINEL BRANCO COM 3 PECAS',
#     'descricao_detalhada': None,
#     'ean': '840102700633',
#     'marca': 'NANOLEAF'},
#    {'id': 5607,
#     'nome': 'NANOLEAF SHAPES TRIANGLES BRANCO COM 7 PECAS',
#     'descricao_detalhada': None,
#     'ean': '840102703238',
#     'marca': 'NANOLEAF'},
#    {'id': 5611,
#     'nome': 'FITA DE LED NANOLEAF ESSENTIALS 1M 30W LIGHTSTRIP EXPANSION',
#     'descricao_detalhada': None,
#     'ean': '840102701722',
#     'marca': 'NANOLEAF'},
#    {'id': 5612,
#     'nome': 'FITA DE LED NANOLEAF ESSENTIALS 2M 30W LIGHTSTRIP SMK',
#     'descricao_detalhada': None,
#     'ean': '840102702484',
#     'marca': 'NANOLEAF'},
#    {'id': 5615,
#     'nome': 'LAMPADA NANOLEAF ESSENTIALS E26 SMART BRANCO',
#     'descricao_detalhada': None,
#     'ean': '840102702897',
#     'marca': 'NANOLEAF'},
#    {'id': 5617,
#     'nome': 'NANOLEAF ELEMENTS HEXAGON APENAS PAINEL BIRCHWOOD COM 3 PECAS',
#     'descricao_detalhada': None,
#     'ean': '840102701661',
#     'marca': 'NANOLEAF'},
#    {'id': 5618,
#     'nome': 'NANOLEAF LINES BRANCO COM 9 PECAS',
#     'descricao_detalhada': None,
#     'ean': '4897105330127',
#     'marca': 'NANOLEAF'},
#    {'id': 5619,
#     'nome': 'NANOLEAF LINES APENAS PAINEL BRANCO COM 3 PECAS',
#     'descricao_detalhada': None,
#     'ean': '4897105330035',
#     'marca': 'NANOLEAF'},
#    {'id': 5634,
#     'nome': 'LUMINARIA INTELIGENTE DIVOOM PLANET-9 VERMELHO',
#     'descricao_detalhada': None,
#     'ean': '6958444602936',
#     'marca': 'DIVOOM'}]},
#  {'id': 77,
#   'codigo': 1129682254,
#   'nome_familia': 'JOYSTICK',
#   'sample_products': [{'id': 4378,
#     'nome': 'CONTROLE COM FIO PARA PC T-DAGGER ARIES T-TGP500',
#     'descricao_detalhada': None,
#     'ean': '6950376774279',
#     'marca': 'T-DAGGER'},
#    {'id': 4410,
#     'nome': 'CONTROLE TAURUS',
#     'descricao_detalhada': None,
#     'ean': '6950376774286',
#     'marca': 'T-DAGGER'},
#    {'id': 4411,
#     'nome': 'CONTROLE VIRGO',
#     'descricao_detalhada': None,
#     'ean': '6950376774293',
#     'marca': 'T-DAGGER'},
#    {'id': 4414,
#     'nome': 'CONTROLE GAMER REDRAGON SATURN',
#     'descricao_detalhada': None,
#     'ean': '6950376750570',
#     'marca': 'REDRAGON'},
#    {'id': 4433,
#     'nome': 'CONTROLE COM FIO MARVO GT-016',
#     'descricao_detalhada': None,
#     'ean': '6932391913147',
#     'marca': 'MARVO'},
#    {'id': 4583,
#     'nome': 'CONTROLE SEYMOUR 2',
#     'descricao_detalhada': None,
#     'ean': '6950376751560',
#     'marca': 'REDRAGON'},
#    {'id': 4589,
#     'nome': 'CONTROLE COM FIO MARVO GT-006',
#     'descricao_detalhada': None,
#     'ean': '6932391902738',
#     'marca': 'MARVO'},
#    {'id': 4937,
#     'nome': 'SIMULADOR DE CORRIDA PARA COMPUTADOR GT-32',
#     'descricao_detalhada': None,
#     'ean': '6950376707956',
#     'marca': 'REDRAGON'},
#    {'id': 6495,
#     'nome': 'CONTROLE REDRAGON HARROW  PRO.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 7314,
#     'nome': 'CONTROLE REDRAGON HARROW  PRO',
#     'descricao_detalhada': None,
#     'ean': '6950376718952',
#     'marca': 'REDRAGON'}]},
#  {'id': 60,
#   'codigo': 1129682237,
#   'nome_familia': 'KEYCAPS',
#   'sample_products': [{'id': 3781,
#     'nome': 'JOGO COMPLETO DE TECLAS PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376750884',
#     'marca': 'REDRAGON'},
#    {'id': 3782,
#     'nome': 'JOGO DE 12 TECLAS CINZA ESCURO',
#     'descricao_detalhada': None,
#     'ean': '6950376750174',
#     'marca': 'REDRAGON'},
#    {'id': 3783,
#     'nome': 'JOGO COMPLETO DE TECLAS BRANCO',
#     'descricao_detalhada': None,
#     'ean': '6950376747006',
#     'marca': 'REDRAGON'},
#    {'id': 3784,
#     'nome': 'JOGO COMPLETO DE TECLAS PRETO A101',
#     'descricao_detalhada': None,
#     'ean': '6950376747020',
#     'marca': 'REDRAGON'},
#    {'id': 4210,
#     'nome': 'JOGO COMPLETO DE TECLAS PRETO A105',
#     'descricao_detalhada': None,
#     'ean': '6950376750730',
#     'marca': 'REDRAGON'},
#    {'id': 4842,
#     'nome': 'KIT KEYCAPS ABNT2 RM PBT A108 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376771995',
#     'marca': 'REDRAGON'},
#    {'id': 5885,
#     'nome': 'JOGO COMPLETO DE TECLAS  SCARAB PBT PRETO ABNT-2',
#     'descricao_detalhada': None,
#     'ean': '6950376712967',
#     'marca': 'REDRAGON'},
#    {'id': 5145,
#     'nome': 'KEYCAPS PERFIL ASA PBT DOUBLE SHOT KIT COM 158 TECLAS MODELO LOS ANGELES',
#     'descricao_detalhada': None,
#     'ean': '6925758607759',
#     'marca': 'AKKO'},
#    {'id': 5146,
#     'nome': 'KEYCAPS PERFIL ASA PBT DOUBLE SHOT KIT COM 226 TECLAS MODELO WAVE',
#     'descricao_detalhada': None,
#     'ean': '6925758610278',
#     'marca': 'AKKO'},
#    {'id': 5147,
#     'nome': 'KEYCAPS PERFIL ASA PBT DOUBLE SHOT KIT COM 199 TECLAS MODELO MACAW',
#     'descricao_detalhada': None,
#     'ean': '6925758610285',
#     'marca': 'AKKO'}]},
#  {'id': 101,
#   'codigo': 7537275456,
#   'nome_familia': 'MEMÓRIA',
#   'sample_products': [{'id': 5485,
#     'nome': 'MEMORIA DDR4 REDRAGON RAGE 3200MHZ/CL16 VERMELHA 16GB.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 5486,
#     'nome': 'MEMORIA DDR4 REDRAGON RAGE 3200MHZ/CL16 VERMELHA 8GB.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 6313,
#     'nome': 'MEMORIA DDR4 REDRAGON RAGE 3200MHZ/CL16 VERMELHA 8GB',
#     'descricao_detalhada': None,
#     'ean': '788115638867',
#     'marca': 'REDRAGON'},
#    {'id': 6314,
#     'nome': 'MEMORIA DDR4 REDRAGON RAGE 3200MHZ/CL16 VERMELHA 16GB',
#     'descricao_detalhada': None,
#     'ean': '0788115638874',
#     'marca': 'REDRAGON'},
#    {'id': 6354,
#     'nome': 'MEMORIA DDR4 REDRAGON FLAME 8GB PRETO',
#     'descricao_detalhada': None,
#     'ean': '0619205757635',
#     'marca': 'REDRAGON'},
#    {'id': 6355,
#     'nome': 'MEMORIA DDR4 REDRAGON FLAME 16GB PRETO.',
#     'descricao_detalhada': None,
#     'ean': '619205757628',
#     'marca': 'REDRAGON'},
#    {'id': 6516,
#     'nome': 'MEMORIA DDR4 REDRAGON MAGMA 3200MHZ/CL18 16GB RGB',
#     'descricao_detalhada': None,
#     'ean': '7898972678265',
#     'marca': 'REDRAGON'},
#    {'id': 6517,
#     'nome': 'MEMORIA DDR4 REDRAGON SOLAR 3600MHZ/CL18 16GB RGB',
#     'descricao_detalhada': None,
#     'ean': '7898972678326',
#     'marca': 'REDRAGON'},
#    {'id': 6520,
#     'nome': 'MEMORIA DDR4 REDRAGON MAGMA 3200MHZ/CL18 32GB RGB',
#     'descricao_detalhada': None,
#     'ean': '7898972678272',
#     'marca': 'REDRAGON'},
#    {'id': 6770,
#     'nome': 'CARTAO DE MEMORIA MICRO SD HIKSEMI NEO 16GB',
#     'descricao_detalhada': None,
#     'ean': '6974202726072',
#     'marca': 'HIKSEMI'}]},
#  {'id': 76,
#   'codigo': 1129682253,
#   'nome_familia': 'MESA DIGITALIZADORA',
#   'sample_products': [{'id': 3966,
#     'nome': 'MESA DIGITALIZADORA STAR G960S PLUS',
#     'descricao_detalhada': None,
#     'ean': '0654913037334',
#     'marca': 'XP-PEN'},
#    {'id': 3967,
#     'nome': 'MESA DIGITALIZADORA STAR G640S',
#     'descricao_detalhada': None,
#     'ean': '0654913039154',
#     'marca': 'XP-PEN'},
#    {'id': 3968,
#     'nome': 'MESA DIGITALIZADORA STAR G430S',
#     'descricao_detalhada': None,
#     'ean': '0708402555844',
#     'marca': 'XP-PEN'},
#    {'id': 3969,
#     'nome': 'MESA DIGITALIZADORA STAR 06C',
#     'descricao_detalhada': None,
#     'ean': '0654913041447',
#     'marca': 'XP-PEN'},
#    {'id': 3970,
#     'nome': 'MESA DIGITALIZADORA NOTE PLUS',
#     'descricao_detalhada': None,
#     'ean': '0654913036580',
#     'marca': 'XP-PEN'},
#    {'id': 3972,
#     'nome': 'MESA DIGITALIZADORA DECO 03',
#     'descricao_detalhada': None,
#     'ean': '0761460827070',
#     'marca': 'XP-PEN'},
#    {'id': 3973,
#     'nome': 'MESA DIGITALIZADORA DECO 02',
#     'descricao_detalhada': None,
#     'ean': '0602258779310',
#     'marca': 'XP-PEN'},
#    {'id': 3974,
#     'nome': 'MESA DIGITALIZADORA DECO 01 V2',
#     'descricao_detalhada': None,
#     'ean': '0654913036948',
#     'marca': 'XP-PEN'},
#    {'id': 3975,
#     'nome': 'MESA DIGITALIZADORA DECO PRO SMALL',
#     'descricao_detalhada': None,
#     'ean': '0654913041270',
#     'marca': 'XP-PEN'},
#    {'id': 3976,
#     'nome': 'MESA DIGITALIZADORA DECO PRO MEDIUM',
#     'descricao_detalhada': None,
#     'ean': '0654913041287',
#     'marca': 'XP-PEN'}]},
#  {'id': 75,
#   'codigo': 1129682252,
#   'nome_familia': 'MICROFONE',
#   'sample_products': [{'id': 3963,
#     'nome': 'MICROFONE GAMER SCORPION MARVO MIC-03',
#     'descricao_detalhada': None,
#     'ean': '6932391921982',
#     'marca': 'MARVO'},
#    {'id': 3964,
#     'nome': 'MICROFONE GAMER STREAMER QUASAR 2',
#     'descricao_detalhada': None,
#     'ean': '6950376780898',
#     'marca': 'REDRAGON'},
#    {'id': 3965,
#     'nome': 'MICROFONE GAMER STREAMER SEYFERT',
#     'descricao_detalhada': None,
#     'ean': '6950376776389',
#     'marca': 'REDRAGON'},
#    {'id': 4488,
#     'nome': 'MICROFONE GAMER STREAMER BLAZAR',
#     'descricao_detalhada': None,
#     'ean': '6950376776402',
#     'marca': 'REDRAGON'},
#    {'id': 4516,
#     'nome': 'MICROFONE MARVO  MIC-01',
#     'descricao_detalhada': None,
#     'ean': '6932391917626',
#     'marca': 'MARVO'},
#    {'id': 5075,
#     'nome': 'MICROFONE GAMER STREAMER ORIOLE',
#     'descricao_detalhada': None,
#     'ean': '6950376706409',
#     'marca': 'T-DAGGER'},
#    {'id': 6048,
#     'nome': 'MICROFONE GAMER NZXT CAPSULE MINI PRETO',
#     'descricao_detalhada': None,
#     'ean': '5056547200811',
#     'marca': 'NZXT'},
#    {'id': 6842,
#     'nome': 'MICROFONE GAMER MAONO DM30 RGB PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237681670',
#     'marca': 'MAONO'},
#    {'id': 6843,
#     'nome': 'MICROFONE GAMER MAONO PD100 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237681410',
#     'marca': 'MAONO'},
#    {'id': 6844,
#     'nome': 'MICROFONE GAMER COM BRAÇO ARTICULAVEL MAONO PD200XS PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237682141',
#     'marca': 'MAONO'}]},
#  {'id': 87,
#   'codigo': 1129682264,
#   'nome_familia': 'MOBILE',
#   'sample_products': [{'id': 4208,
#     'nome': 'CONTROLE E SUPORTE MOBILE',
#     'descricao_detalhada': None,
#     'ean': '7897473191570',
#     'marca': 'REDRAGON'},
#    {'id': 4209,
#     'nome': 'GATILHO PARA FPS TRIGGER',
#     'descricao_detalhada': None,
#     'ean': '7897473191563',
#     'marca': 'REDRAGON'}]},
#  {'id': 74,
#   'codigo': 1129682251,
#   'nome_familia': 'MOCHILA',
#   'sample_products': [{'id': 3962,
#     'nome': 'M MOCHILA MARCA MARVO MODELO BA-02',
#     'descricao_detalhada': None,
#     'ean': '6932391921890',
#     'marca': 'MARVO'},
#    {'id': 5637,
#     'nome': 'MOCHILA DIVOOM COM PAINEL EM ARTE PIXEL PIXOO-SLINGBAG-V',
#     'descricao_detalhada': None,
#     'ean': '6958444603803',
#     'marca': 'DIVOOM'},
#    {'id': 5642,
#     'nome': 'MOCHILA DIVOOM COM PAINEL EM ARTE PIXEL PIXOO-SLINGBAG PRETO',
#     'descricao_detalhada': None,
#     'ean': '6958444603612',
#     'marca': 'DIVOOM'},
#    {'id': 5643,
#     'nome': 'MOCHILA DIVOOM COM PAINEL EM ARTE PIXEL DIVOOM-BACKPACK-S',
#     'descricao_detalhada': None,
#     'ean': '6958444603759',
#     'marca': 'DIVOOM'},
#    {'id': 6429,
#     'nome': 'MOCHILA REDRAGON GB-93 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376704702',
#     'marca': 'REDRAGON'},
#    {'id': 6430,
#     'nome': 'MOCHILA REDRAGON GB-94 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376772695',
#     'marca': 'REDRAGON'},
#    {'id': 6431,
#     'nome': 'MOCHILA REDRAGON GB-82 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376772688',
#     'marca': 'REDRAGON'},
#    {'id': 6432,
#     'nome': 'MOCHILA REDRAGON GB-76 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376704764',
#     'marca': 'REDRAGON'},
#    {'id': 5644,
#     'nome': 'MOCHILA DIVOOM COM PAINEL EM ARTE PIXEL DIVOOM-BACKPACK-M',
#     'descricao_detalhada': None,
#     'ean': '6958444603711',
#     'marca': 'DIVOOM'},
#    {'id': 5694,
#     'nome': 'MOCHILA DIVOOM COM PAINEL EM ARTE PIXEL PIXOO SLINGBAG-C PRETO',
#     'descricao_detalhada': None,
#     'ean': '6958444603971',
#     'marca': 'DIVOOM'}]},
#  {'id': 73,
#   'codigo': 1129682250,
#   'nome_familia': 'MONITORES',
#   'sample_products': [{'id': 3957,
#     'nome': 'MONITOR BLACK MAGIC 144 HZ 27 POLEGADAS C LIFT',
#     'descricao_detalhada': None,
#     'ean': '6950376777003',
#     'marca': 'REDRAGON'},
#    {'id': 3958,
#     'nome': 'MONITOR REDIAMOND 144 HZ 24,5 POLEGADAS C LIFT',
#     'descricao_detalhada': None,
#     'ean': '6950376776990',
#     'marca': 'REDRAGON'},
#    {'id': 3959,
#     'nome': 'MONITOR GAMER MIRROR 23,6&quot; 144 HZ TELA CURVA',
#     'descricao_detalhada': None,
#     'ean': '6950376776983',
#     'marca': 'REDRAGON'},
#    {'id': 3960,
#     'nome': 'MONITOR GAMER REDRAGON JADE 27 POLEGADAS 165HZ GM3CC27',
#     'descricao_detalhada': None,
#     'ean': '6950376780669',
#     'marca': 'REDRAGON'},
#    {'id': 3961,
#     'nome': 'MONITOR GAMER REDRAGON RUBY 23,8 POLEGADAS 144HZ GM3CC238',
#     'descricao_detalhada': None,
#     'ean': '6950376781475',
#     'marca': 'REDRAGON'},
#    {'id': 4911,
#     'nome': 'MONITOR GAMER REDRAGON SAPPHIRE 23,8 POL 144HZ FREESYNC DP/VGA/HDMI',
#     'descricao_detalhada': None,
#     'ean': '6950376705624',
#     'marca': 'REDRAGON'},
#    {'id': 4912,
#     'nome': 'MONITOR GAMER REDRAGON EMERALD 27 POL 165HZ FREESYNC DP/DVI/HDMI',
#     'descricao_detalhada': None,
#     'ean': '6950376704818',
#     'marca': 'REDRAGON'},
#    {'id': 5072,
#     'nome': 'MONITOR GAMER REDRAGON CITRINE 30 POL 200HZ TELA CURVA',
#     'descricao_detalhada': None,
#     'ean': '6950376707970',
#     'marca': 'REDRAGON'},
#    {'id': 6295,
#     'nome': 'MONITOR GAMER REDRAGON CORAL 27 POL 170Hz CURVE-2560x1440-2K',
#     'descricao_detalhada': None,
#     'ean': '6950376719195',
#     'marca': 'REDRAGON'},
#    {'id': 6296,
#     'nome': 'MONITOR GAMER REDRAGON PEARL 23.6 POL 165Hz 1800R-CURVE',
#     'descricao_detalhada': None,
#     'ean': '6950376715104',
#     'marca': 'REDRAGON'}]},
#  {'id': 72,
#   'codigo': 1129682249,
#   'nome_familia': 'MOUSE',
#   'sample_products': [{'id': 3920,
#     'nome': 'MOUSE AIRCRAFTMAN PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376774958',
#     'marca': 'T-DAGGER'},
#    {'id': 3921,
#     'nome': 'MOUSE CAPTAIN PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376783998',
#     'marca': 'T-DAGGER'},
#    {'id': 3922,
#     'nome': 'MOUSE GAMER LIEUTENANT PTO RGB',
#     'descricao_detalhada': None,
#     'ean': '6950376784001',
#     'marca': 'T-DAGGER'},
#    {'id': 3923,
#     'nome': 'MOUSE LANCE CORPORAL PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376774354',
#     'marca': 'T-DAGGER'},
#    {'id': 3925,
#     'nome': 'MOUSE GAMER RGB KWG ORION M1 (ORION M1)',
#     'descricao_detalhada': None,
#     'ean': '4712960134164',
#     'marca': 'KWG'},
#    {'id': 3926,
#     'nome': 'MOUSE COM FIO ONEPOWER MO505',
#     'descricao_detalhada': None,
#     'ean': '7897473191518',
#     'marca': 'ONEPOWER'},
#    {'id': 3927,
#     'nome': 'MOUSE GAMER STORM ELITE RGB PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376778536',
#     'marca': 'REDRAGON'},
#    {'id': 3928,
#     'nome': 'MOUSE RANGER PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376774231',
#     'marca': 'REDRAGON'},
#    {'id': 3929,
#     'nome': 'MOUSE STORM RGB LUNAR WHITE',
#     'descricao_detalhada': None,
#     'ean': '6950376779335',
#     'marca': 'REDRAGON'},
#    {'id': 3931,
#     'nome': 'MOUSE M801-RGB SNIPER PRETO M801-RGB',
#     'descricao_detalhada': None,
#     'ean': '6950376776082',
#     'marca': 'REDRAGON'}]},
#  {'id': 71,
#   'codigo': 1129682248,
#   'nome_familia': 'MOUSEPAD',
#   'sample_products': [{'id': 3891,
#     'nome': 'MOUSEPAD 780X300X3MM LAVA L',
#     'descricao_detalhada': None,
#     'ean': '6950376774491',
#     'marca': 'T-DAGGER'},
#    {'id': 3892,
#     'nome': 'MOUSEPAD GAMER GEOMETRY-M',
#     'descricao_detalhada': None,
#     'ean': '6950376774484',
#     'marca': 'T-DAGGER'},
#    {'id': 3893,
#     'nome': 'MOUSEPAD 360X300X3MM LAVA M',
#     'descricao_detalhada': None,
#     'ean': '6950376774477',
#     'marca': 'T-DAGGER'},
#    {'id': 3894,
#     'nome': 'MOUSEPAD GAMER GEOMETRY-S',
#     'descricao_detalhada': None,
#     'ean': '6950376774460',
#     'marca': 'T-DAGGER'},
#    {'id': 3895,
#     'nome': 'MOUSEPAD 290X240X3MM LAVA S',
#     'descricao_detalhada': None,
#     'ean': '6950376774439',
#     'marca': 'T-DAGGER'},
#    {'id': 3896,
#     'nome': 'MOUSEPAD GAMER FLICK XL',
#     'descricao_detalhada': None,
#     'ean': '6950376779908',
#     'marca': 'REDRAGON'},
#    {'id': 3897,
#     'nome': 'MOUSEPAD GAMER FLICK L',
#     'descricao_detalhada': None,
#     'ean': '6950376779892',
#     'marca': 'REDRAGON'},
#    {'id': 3898,
#     'nome': 'MOUSEPAD GAMER REDRAGON FLICK M P030',
#     'descricao_detalhada': None,
#     'ean': '6950376779885',
#     'marca': 'REDRAGON'},
#    {'id': 3899,
#     'nome': 'MOUSEPAD GAMER RGB NEPTUNE',
#     'descricao_detalhada': None,
#     'ean': '6950376775894',
#     'marca': 'REDRAGON'},
#    {'id': 3901,
#     'nome': 'MOUSEPAD 330X260X3MM PISCES',
#     'descricao_detalhada': None,
#     'ean': '6950376782298',
#     'marca': 'REDRAGON'}]},
#  {'id': 114,
#   'codigo': 10597965118,
#   'nome_familia': 'NOBREAK',
#   'sample_products': [{'id': 7550,
#     'nome': 'NOBREAK ONE UP NITRO 2000 RGB TI RED 60HZ ENTR. 115-127-220V SAI. 115V',
#     'descricao_detalhada': None,
#     'ean': '7897072045939',
#     'marca': 'REDRAGON'}]},
#  {'id': 69,
#   'codigo': 1129682246,
#   'nome_familia': 'PASTA TÉRMICA',
#   'sample_products': [{'id': 3873,
#     'nome': 'PASTA TERMICA KRYONAUT GRIZZLY 1G',
#     'descricao_detalhada': None,
#     'ean': '0753677507234',
#     'marca': 'GRIZZLY'},
#    {'id': 3874,
#     'nome': 'PASTA TERMICA HYDRONAUT GRIZZLY 1G',
#     'descricao_detalhada': None,
#     'ean': '0753677507586',
#     'marca': 'GRIZZLY'},
#    {'id': 3875,
# ...
#     'marca': 'MAONO'},
#    {'id': 6848,
#     'nome': 'KIT STREAM DECK MAONO CASTER LITE PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237680413',
#     'marca': 'MAONO'},
#    {'id': 7025,
#     'nome': 'STREAM DECK MAONO CASTER G1 NEO PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237682257',
#     'marca': 'MAONO'},
#    {'id': 7307,
#     'nome': 'STREAM DECK MAONO CASTER G2 PRETO',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'MAONO'}]},
#  {'id': 66,
#   'codigo': 1129682243,
#   'nome_familia': 'SUPORTE PARA HEADSET',
#   'sample_products': [{'id': 3864,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB PRO.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 4817,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB PRO BRANCO.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 5594,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB ELITE',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'REDRAGON'},
#    {'id': 6551,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB PRO PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376775955',
#     'marca': 'REDRAGON'},
#    {'id': 6552,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB PRO BRANCO',
#     'descricao_detalhada': None,
#     'ean': '6950376704757',
#     'marca': 'REDRAGON'},
#    {'id': 6553,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB ELITE PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376705563',
#     'marca': 'REDRAGON'},
#    {'id': 6554,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER RGB ELITE BRANCO',
#     'descricao_detalhada': None,
#     'ean': '6950376720559',
#     'marca': 'REDRAGON'},
#    {'id': 6556,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER X PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376707499',
#     'marca': 'REDRAGON'},
#    {'id': 6555,
#     'nome': 'SUPORTE PARA HEADSET SCEPTER X BRANCO',
#     'descricao_detalhada': None,
#     'ean': '6950376720825',
#     'marca': 'REDRAGON'}]},
#  {'id': 108,
#   'codigo': 10458435644,
#   'nome_familia': 'SUPORTE PARA MICROFONE',
#   'sample_products': [{'id': 6434,
#     'nome': 'SUPORTE DE MICROFONE NZXT SWITCHMIX PRETO',
#     'descricao_detalhada': None,
#     'ean': '5056547202853',
#     'marca': 'NZXT'},
#    {'id': 7021,
#     'nome': 'BRAÇO DE MICROFONE MAONO BA92 PRETO.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': 'MAONO'},
#    {'id': 7218,
#     'nome': 'FILTRO POP DE MICROFONE MAONO AU-PF150 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237680352',
#     'marca': 'MAONO'},
#    {'id': 7305,
#     'nome': 'BRAÇO DE MICROFONE MAONO BA92 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237681823',
#     'marca': 'MAONO'},
#    {'id': 7306,
#     'nome': 'BRAÇO DE MICROFONE MAONO BA20 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237682332',
#     'marca': 'MAONO'},
#    {'id': 6849,
#     'nome': 'BRAÇO DE MICROFONE MAONO AU-B01 PRETO',
#     'descricao_detalhada': None,
#     'ean': '6972237680307',
#     'marca': 'MAONO'}]},
#  {'id': 92,
#   'codigo': 1515075769,
#   'nome_familia': 'SUPORTE PARA NOTEBOOK',
#   'sample_products': [{'id': 4818,
#     'nome': 'SUPORTE PARA NOTEBOOK BLACK COM 2 FANS',
#     'descricao_detalhada': None,
#     'ean': '6933412775607',
#     'marca': 'DEEPCOOL'},
#    {'id': 4954,
#     'nome': 'SUPORTE PARA NOTEBOOK N8 BLACK COM 2 FANS',
#     'descricao_detalhada': None,
#     'ean': '6933412706786',
#     'marca': 'DEEPCOOL'},
#    {'id': 4956,
#     'nome': 'SUPORTE PARA NOTEBOOK WIND PAL FS BLACK COM 2 FANS',
#     'descricao_detalhada': None,
#     'ean': '6933412708728',
#     'marca': 'DEEPCOOL'},
#    {'id': 4958,
#     'nome': 'SUPORTE PARA NOTEBOOK MULTI CORE X8 BLACK COM 4 FANS',
#     'descricao_detalhada': None,
#     'ean': '6933412775249',
#     'marca': 'DEEPCOOL'},
#    {'id': 4959,
#     'nome': 'SUPORTE PARA NOTEBOOK N200 BLACK COM 1 FAN',
#     'descricao_detalhada': None,
#     'ean': '6933412703266',
#     'marca': 'DEEPCOOL'},
#    {'id': 4960,
#     'nome': 'SUPORTE PARA NOTEBOOK N8 WHITE COM 2 FANS',
#     'descricao_detalhada': None,
#     'ean': '6933412704560',
#     'marca': 'DEEPCOOL'},
#    {'id': 4961,
#     'nome': 'SUPORTE PARA NOTEBOOK N9 BLACK COM 1 FAN',
#     'descricao_detalhada': None,
#     'ean': '6933412775775',
#     'marca': 'DEEPCOOL'},
#    {'id': 4962,
#     'nome': 'SUPORTE PARA NOTEBOOK N9 WHITE COM 1 FAN',
#     'descricao_detalhada': None,
#     'ean': '6933412708629',
#     'marca': 'DEEPCOOL'},
#    {'id': 4963,
#     'nome': 'SUPORTE PARA NOTEBOOK MULTI CORE X6 BLACK COM 4 FANS',
#     'descricao_detalhada': None,
#     'ean': '6933412725220',
#     'marca': 'DEEPCOOL'},
#    {'id': 4964,
#     'nome': 'SUPORTE PARA NOTEBOOK M-DESK F1 WHITE',
#     'descricao_detalhada': None,
#     'ean': '6933412775652',
#     'marca': 'DEEPCOOL'}]},
#  {'id': 95,
#   'codigo': 6759916663,
#   'nome_familia': 'SWITCH',
#   'sample_products': [{'id': 5125,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 45 MODELO ROSE RED',
#     'descricao_detalhada': None,
#     'ean': '6925758609326',
#     'marca': 'AKKO'},
#    {'id': 5126,
#     'nome': 'SWITCH PARA TECLADO MECANICO TACTILE KIT COM 45 MODELO OCEAN BLUE',
#     'descricao_detalhada': None,
#     'ean': '6925758609340',
#     'marca': 'AKKO'},
#    {'id': 5127,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 45 MODELO MATCHA GREEN',
#     'descricao_detalhada': None,
#     'ean': '6925758609333',
#     'marca': 'AKKO'},
#    {'id': 5128,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 45 MODELO RADIANT RED',
#     'descricao_detalhada': None,
#     'ean': '6925758611336',
#     'marca': 'AKKO'},
#    {'id': 5129,
#     'nome': 'SWITCH PARA TECLADO MECANICO TACTILE KIT COM 45 MODELO LAVENDER PURPLE',
#     'descricao_detalhada': None,
#     'ean': '6925758611329',
#     'marca': 'AKKO'},
#    {'id': 5130,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 45 MODELO VINTAGE WHITE',
#     'descricao_detalhada': None,
#     'ean': '6925758611312',
#     'marca': 'AKKO'},
#    {'id': 5131,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 10 MODELO AKKO X TTC DEMON',
#     'descricao_detalhada': None,
#     'ean': '6925758615006',
#     'marca': 'AKKO'},
#    {'id': 5132,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 10 MODELO AKKO X TTC PRINCESS',
#     'descricao_detalhada': None,
#     'ean': '6925758614993',
#     'marca': 'AKKO'},
#    {'id': 5133,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 45 MODELO JELLY BLACK',
#     'descricao_detalhada': None,
#     'ean': '6925758614443',
#     'marca': 'AKKO'},
#    {'id': 5134,
#     'nome': 'SWITCH PARA TECLADO MECANICO LINEAR KIT COM 45 MODELO JELLY PINK',
#     'descricao_detalhada': None,
#     'ean': '6925758614436',
#     'marca': 'AKKO'}]},
#  {'id': 97,
#   'codigo': 6763892705,
#   'nome_familia': 'TECLADO DIY',
#   'sample_products': [{'id': 5181,
#     'nome': 'BASE DE TECLADO DIY MODELO MOD005 GRAY',
#     'descricao_detalhada': None,
#     'ean': '6925758615969',
#     'marca': 'AKKO'},
#    {'id': 5182,
#     'nome': 'BASE DE TECLADO DIY MODELO MOD005 PINK',
#     'descricao_detalhada': None,
#     'ean': '6925758615983',
#     'marca': 'AKKO'},
#    {'id': 5183,
#     'nome': 'BASE DE TECLADO DIY MODELO MOD007 V2 SPACE GRAY',
#     'descricao_detalhada': None,
#     'ean': '6925758617864',
#     'marca': 'AKKO'},
#    {'id': 5184,
#     'nome': 'BASE DE TECLADO DIY MODELO MOD007 V2 MIDNIGHT BLUE',
#     'descricao_detalhada': None,
#     'ean': '6925758617888',
#     'marca': 'AKKO'},
#    {'id': 6448,
#     'nome': 'BASE DE TECLADO DIY MODELO MOD007B-HE PRETO',
#     'descricao_detalhada': None,
#     'ean': '6925758626873',
#     'marca': 'AKKO'},
#    {'id': 6449,
#     'nome': 'BASE DE TECLADO DIY MODELO MOD007B-HE BRANCO',
#     'descricao_detalhada': None,
#     'ean': '6925758626880',
#     'marca': 'AKKO'}]},
#  {'id': 64,
#   'codigo': 1129682241,
#   'nome_familia': 'TECLADO MECANICO',
#   'sample_products': [{'id': 3810,
#     'nome': 'TECLADO MECANICO MARVO RAINBOW SWITCH AZUL KG901',
#     'descricao_detalhada': None,
#     'ean': '6932391920954',
#     'marca': 'MARVO'},
#    {'id': 3811,
#     'nome': 'TECLADO MECANICO GAMER IDA RGB PTO SWITCH AZUL',
#     'descricao_detalhada': None,
#     'ean': '6950376774378',
#     'marca': 'REDRAGON'},
#    {'id': 3815,
#     'nome': 'TECLADO GAMER MECANICO SANI SWITCH AZUL  RGB PRETO',
#     'descricao_detalhada': None,
#     'ean': '6950376777461',
#     'marca': 'REDRAGON'},
#    {'id': 3817,
#     'nome': 'TECLADO MECANICO GAMER MANYU RGB PTO SWITCH AZUL ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376776044',
#     'marca': 'REDRAGON'},
#    {'id': 3818,
#     'nome': 'TECLADO MECANICO GAMER DAKSA PTO RAINBOW SWITCH AZUL ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376780263',
#     'marca': 'REDRAGON'},
#    {'id': 3819,
#     'nome': 'TECLADO MECANICO GAMER ARYAMAN RGB PTO SWITCH AZUL ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376775511',
#     'marca': 'REDRAGON'},
#    {'id': 3820,
#     'nome': 'TECLADO MECANICO DARK AVENGER RGB BCO SWITCH PRETO ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376777706',
#     'marca': 'REDRAGON'},
#    {'id': 3821,
#     'nome': 'TECLADO MECANICO DARK AVENGER RGB SWITCH VERMELHO',
#     'descricao_detalhada': None,
#     'ean': '6950376776945',
#     'marca': 'REDRAGON'},
#    {'id': 3822,
#     'nome': 'TECLADO MECANICO GAMER DARK AVENGER RGB SWITCH MARROM',
#     'descricao_detalhada': None,
#     'ean': '6950376776532',
#     'marca': 'REDRAGON'},
#    {'id': 3823,
#     'nome': 'TECLADO MECANICO GAMER  DARK AVENGER RGB SWITCH AZUL',
#     'descricao_detalhada': None,
#     'ean': '6950376776525',
#     'marca': 'REDRAGON'}]},
#  {'id': 62,
#   'codigo': 1129682239,
#   'nome_familia': 'TECLADO MEMBRANA',
#   'sample_products': [{'id': 3794,
#     'nome': 'TECLADO GAMER MEMBRANA XTRIKE ME RAINBOW KB-508',
#     'descricao_detalhada': None,
#     'ean': '6932391922361',
#     'marca': 'XTRIKE ME'},
#    {'id': 3801,
#     'nome': 'TECLADO GAMER MEMBRANA RAINBOW XTRIKE ME KB-507',
#     'descricao_detalhada': None,
#     'ean': '6932391922323',
#     'marca': 'XTRIKE ME'},
#    {'id': 3802,
#     'nome': 'TECLADO GAMER MEMBRANA XTRIKE ME RAINBOW KB-302',
#     'descricao_detalhada': None,
#     'ean': '6932391917527',
#     'marca': 'XTRIKE ME'},
#    {'id': 3803,
#     'nome': 'TECLADO GAMER MEMBRANA SCORPION MARVO RAINBOW K606',
#     'descricao_detalhada': None,
#     'ean': '6932391922286',
#     'marca': 'MARVO'},
#    {'id': 3804,
#     'nome': 'TECLADO MEMBRANA GAMER HARPE RGB PTO',
#     'descricao_detalhada': None,
#     'ean': '6950376783202',
#     'marca': 'REDRAGON'},
#    {'id': 3805,
#     'nome': 'TECLADO MEMBRANA RGB PRETO KARURA 2',
#     'descricao_detalhada': None,
#     'ean': '6950376776242',
#     'marca': 'REDRAGON'},
#    {'id': 4282,
#     'nome': 'TECLADO MEMBRANA GAMER T-DAGGER SUBMARINE RGB PTO',
#     'descricao_detalhada': None,
#     'ean': '6950376777409',
#     'marca': 'T-DAGGER'},
#    {'id': 4283,
#     'nome': 'TECLADO MEMBRANA GAMER T-DAGGER TANKER RAINBOW PTO',
#     'descricao_detalhada': None,
#     'ean': '6950376777416',
#     'marca': 'T-DAGGER'},
#    {'id': 4417,
#     'nome': 'TECLADO MEMBRANA TANKER RGB TGK202',
#     'descricao_detalhada': None,
#     'ean': '6950376774989',
#     'marca': 'T-DAGGER'},
#    {'id': 4506,
#     'nome': 'TECLADO MEMBRANA GAMER SCORPION RAINBOW PTO k656',
#     'descricao_detalhada': None,
#     'ean': '6932391920947',
#     'marca': 'MARVO'}]},
#  {'id': 63,
#   'codigo': 1129682240,
#   'nome_familia': 'TECLADO OPTICO',
#   'sample_products': [{'id': 3797,
#     'nome': 'TECLADO OPTICO GAMER  AMSA PRO RGB PTO SWITCH AZUL',
#     'descricao_detalhada': None,
#     'ean': '6950376778499',
#     'marca': 'REDRAGON'},
#    {'id': 3799,
#     'nome': 'TECLADO OPTICO GAMER MAGIC-WAND PRO RGB PTO SWITCH AZUL ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376778475',
#     'marca': 'REDRAGON'},
#    {'id': 3800,
#     'nome': 'TECLADO OPTICO GAMER BRAHMA PRO RGB  PTO SWITCH AZUL',
#     'descricao_detalhada': None,
#     'ean': '6950376778468',
#     'marca': 'REDRAGON'},
#    {'id': 3813,
#     'nome': 'TECLADO OPTICO GAMER SURARA PRO RGB PTO SWITCH MARROM ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376778444',
#     'marca': 'REDRAGON'},
#    {'id': 3814,
#     'nome': 'TECLADO OPTICO GAMER  SURARA PRO RGB PTO SWITCH AZUL ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376778420',
#     'marca': 'REDRAGON'},
#    {'id': 3816,
#     'nome': 'TECLADO OPTICO GAMER VATA PRO RGB PTO  SWITCH AZUL ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376778451',
#     'marca': 'REDRAGON'},
#    {'id': 4538,
#     'nome': 'TECLADO OPTICO GAMER MAGIC-WAND PRO RGB PTO SWITCH VERMELHO ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376771988',
#     'marca': 'REDRAGON'},
#    {'id': 4647,
#     'nome': 'TECLADO OPTICO GAMER INFERNAL DRAGON VISERION KEYBOARD ID582',
#     'descricao_detalhada': None,
#     'ean': '6950376781604',
#     'marca': 'REDRAGON'},
#    {'id': 4976,
#     'nome': 'TECLADO OPTICO GAMER MAGIC-WAND PRO RGB BRANCO SWITCH MARROM ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376705037',
#     'marca': 'REDRAGON'},
#    {'id': 4977,
#     'nome': 'TECLADO OPTICO GAMER SURARA PRO RGB BRANCO SWITCH MARROM ABNT2',
#     'descricao_detalhada': None,
#     'ean': '6950376705006',
#     'marca': 'REDRAGON'}]},
#  {'id': 59,
#   'codigo': 1129682236,
#   'nome_familia': 'WATER COOLER',
#   'sample_products': [{'id': 3766,
#     'nome': 'WATER COOLER ALSEYE RGB PRETO M360',
#     'descricao_detalhada': None,
#     'ean': '4897059874098',
#     'marca': 'ALSEYE'},
#    {'id': 3767,
#     'nome': 'WATER COOLER ALSEYE RGB BRANCO M240',
#     'descricao_detalhada': None,
#     'ean': '4897059874050',
#     'marca': 'ALSEYE'},
#    {'id': 3768,
#     'nome': 'WATER COOLER ALSEYE RGB PRETO M240',
#     'descricao_detalhada': None,
#     'ean': '4897059874067',
#     'marca': 'ALSEYE'},
#    {'id': 3769,
#     'nome': 'WATER COOLER ALSEYE RGB BRANCO M120',
#     'descricao_detalhada': None,
#     'ean': '4897059874081',
#     'marca': 'ALSEYE'},
#    {'id': 3770,
#     'nome': 'WATER COOLER ALSEYE RGB PRETO M120',
#     'descricao_detalhada': None,
#     'ean': '4897059874074',
#     'marca': 'ALSEYE'},
#    {'id': 3771,
#     'nome': 'WATER COOLER ALSEYE HALO RAINBOW PRETO H360',
#     'descricao_detalhada': None,
#     'ean': '4897059871837',
#     'marca': 'ALSEYE'},
#    {'id': 3772,
#     'nome': 'WATER COOLER ALSEYE HALO RAINBOW PRETO H280',
#     'descricao_detalhada': None,
#     'ean': '4897059873411',
#     'marca': 'ALSEYE'},
#    {'id': 3774,
#     'nome': 'WATER COOLER ALSEYE HALO RAINBOW PRETO H120',
#     'descricao_detalhada': None,
#     'ean': '4897059871813',
#     'marca': 'ALSEYE'},
#    {'id': 3775,
#     'nome': 'WATER COOLER GALAHAD 240 RGB BRANCO',
#     'descricao_detalhada': None,
#     'ean': '4718466009395',
#     'marca': 'LIAN LI'},
#    {'id': 3776,
#     'nome': 'WATER COOLER ANTI-LEAK RGB GAMMAXX L240 V2',
#     'descricao_detalhada': None,
#     'ean': '6933412726623',
#     'marca': 'DEEPCOOL'}]},
#  {'id': 58,
#   'codigo': 1129682235,
#   'nome_familia': 'WEBCAM',
#   'sample_products': [{'id': 3764,
#     'nome': 'WEBCAM GAMER STREAMING FOBOS GW600',
#     'descricao_detalhada': None,
#     'ean': '6950376778871',
#     'marca': 'REDRAGON'},
#    {'id': 4710,
#     'nome': 'WEBCAM STREAMING EAGLE HD 720P',
#     'descricao_detalhada': None,
#     'ean': '6950376780423',
#     'marca': 'T-DAGGER'},
#    {'id': 4841,
#     'nome': 'WEBCAM STREAMING APEX 2 GW900-1',
#     'descricao_detalhada': None,
#     'ean': '6950376772299',
#     'marca': 'REDRAGON'},
#    {'id': 4902,
#     'nome': 'WEBCAM GAMER STREAMING FOBOS 2 GW600-1',
#     'descricao_detalhada': None,
#     'ean': '6950376772275',
#     'marca': 'REDRAGON'},
#    {'id': 5235,
#     'nome': 'Produto Teste PE. webcam.',
#     'descricao_detalhada': None,
#     'ean': '',
#     'marca': ''},
#    {'id': 5363,
#     'nome': 'WEBCAM GAMER CREATIVE LIVE CAM SYNC 1080P V2 PRETO',
#     'descricao_detalhada': None,
#     'ean': '5390660194696',
#     'marca': 'CREATIVE'},
#    {'id': 3762,
#     'nome': 'WEBCAM STREAMING APEX GW900',
#     'descricao_detalhada': None,
#     'ean': '6950376778635',
#     'marca': 'REDRAGON'},
#    {'id': 3763,
#     'nome': 'WEBCAM GAMER STREAMING HITMAN GW800',
#     'descricao_detalhada': None,
#     'ean': '6950376778864',
#     'marca': 'REDRAGON'}]}]

# %%
import asyncio
from typing import Dict, Any, List
from pydantic import BaseModel, Field
from pydantic_ai import Agent
import json
from tqdm import tqdm

class ProductFamilySpecSchema(BaseModel):
    """Schema definition for a product family's specifications."""
    family_id: int = Field(description="ID of the product family")
    family_name: str = Field(description="Name of the product family")
    specs_schema: Dict[str, Dict[str, Any]] = Field(
        description="JSON schema for the specifications of this product family"
    )

async def generate_family_spec_schema(family_id: int, family_name: str) -> ProductFamilySpecSchema:
    """
    Generate a specification schema for a given product family.
    
    Args:
        family_id: ID of the product family
        family_name: Name of the product family
        
    Returns:
        A structured schema for the product family's specifications
    """
    spec_schema_generator = Agent(
        'openai:o3-mini',
        result_type=ProductFamilySpecSchema,
        retries=3,
        system_prompt="""
        You are a product specification schema expert. Your task is to create a JSON schema that defines 
        the structure of specifications for a specific product family in the computer hardware and peripherals domain.
        
        Guidelines:
        - Use snake_case for all keys
        - Define appropriate data types for each specification (string, integer, float, boolean, array, object)
        - For each field, include:
          * type: The data type
          * description: A brief description in Portuguese
          * format (if applicable): Any specific format requirements
          * enum (if applicable): Possible values for enumerated types
        - Focus on specifications that are commonly used for comparison and decision-making
        - Use Portuguese for all descriptions and enum values
        - Keep the schema concise but comprehensive enough for meaningful product comparisons
        
        The schema should follow this pattern for each specification:
        
        {
          "spec_name": {
            "type": "string|integer|number|boolean|array|object",
            "description": "Description in Portuguese",
            "format": "Optional format specification",
            "enum": ["Value1", "Value2"] // If applicable
          }
        }
        
        For example, for a mouse, one field might be:
        
        {
          "dpi_maximo": {
            "type": "integer",
            "description": "Resolução máxima do sensor em DPI (Dots Per Inch)",
            "minimum": 100
          }
        }
        """
    )
    
    # Create a prompt that includes the family information
    prompt = f"""
    Generate a specification schema for the product family:
    
    Family ID: {family_id}
    Family Name: {family_name}
    
    Create a comprehensive but practical schema that captures the most important 
    specifications for this type of product. Focus on specifications that consumers 
    would use to compare products and make purchasing decisions.
    """
    
    result = await spec_schema_generator.run(prompt)
    return result.data

async def process_all_families(families: List[Dict[str, Any]]) -> List[ProductFamilySpecSchema]:
    """Process all product families to generate specification schemas."""
    results = []
    
    # Create a progress bar
    for family in tqdm(families, desc="Processing families", unit="family"):
        # Skip empty family names
        if not family["nome_familia"]:
            continue
            
        try:
            print(f"Processing family: {family['nome_familia']} (ID: {family['id']})")
            schema = await generate_family_spec_schema(family["id"], family["nome_familia"])
            results.append(schema)
            print(f"Family Schema: {schema}")
            # Save intermediate results to avoid losing progress
            with open(f"family_spec_{family['id']}.json", "w", encoding="utf-8") as f:
                json.dump(schema.model_dump(), f, ensure_ascii=False, indent=2)
                
        except Exception as e:
            print(f"Error processing family {family['nome_familia']}: {str(e)}")
    
    # Save complete results
    with open("all_solid_family_specs.json", "w", encoding="utf-8") as f:
        json.dump([r.model_dump() for r in results], f, ensure_ascii=False, indent=2)
        
    return results

# %%
# Process a subset of families for testing (comment this out to process all)
test_families = product_families[:10]  
family_specs = await process_all_families(test_families)


# Uncomment to process all families
# family_specs = process_all_families(product_families)
# Out:
# Processing family: ACESSÓRIOS GABINETE (ID: 65)
# Processing family: ACESSÓRIOS OFFICE (ID: 113)
# Processing family: ADAPTADOR USB WIFI (ID: 109)
# Processing family: AIR COOLER (ID: 81)
# Processing family: APOIO PARA TECLADO (ID: 85)
# Processing family: AUTO CARE (ID: 104)
# Processing family: BERMUDA (ID: 93)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Process a subset of families for testing (comment this out to process all)
#       2 test_families = product_families[:10]
# ----> 3 family_specs = await process_all_families(test_families)
#       6 # Uncomment to process all families
#       7 # family_specs = process_all_families(product_families)
#
# Cell In[27], line 95, in process_all_families(families)
#      93 try:
#      94     print(f"Processing family: {family['nome_familia']} (ID: {family['id']})")
# ---> 95     schema = await generate_family_spec_schema(family["id"], family["nome_familia"])
#      96     results.append(schema)
#      98     # Save intermediate results to avoid losing progress
#
# Cell In[27], line 81, in generate_family_spec_schema(family_id, family_name)
#      69 # Create a prompt that includes the family information
#      70 prompt = f"""
#      71 Generate a specification schema for the product family:
#      72
#    (...)
#      78 would use to compare products and make purchasing decisions.
#      79 """
# ---> 81 result = await spec_schema_generator.run(prompt)
#      82 return result.data
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_ai/agent.py:326, in Agent.run(self, user_prompt, result_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name)
#     315     self._infer_name(inspect.currentframe())
#     316 async with self.iter(
#     317     user_prompt=user_prompt,
#     318     result_type=result_type,
#    (...)
#     324     usage=usage,
#     325 ) as agent_run:
# --> 326     async for _ in agent_run:
#     327         pass
#     329 assert (final_result := agent_run.result) is not None, 'The graph run did not finish properly'
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_ai/agent.py:1413, in AgentRun.__anext__(self)
#    1409 async def __anext__(
#    1410     self,
#    1411 ) -> _agent_graph.AgentNode[AgentDepsT, ResultDataT] | End[FinalResult[ResultDataT]]:
#    1412     """Advance to the next node automatically based on the last returned node."""
# -> 1413     next_node = await self._graph_run.__anext__()
#    1414     if _agent_graph.is_agent_node(next_node):
#    1415         return next_node
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_graph/graph.py:782, in GraphRun.__anext__(self)
#     780 if isinstance(self._next_node, End):
#     781     raise StopAsyncIteration
# --> 782 return await self.next(self._next_node)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_graph/graph.py:760, in GraphRun.next(self, node)
#     758     async with self.persistence.record_run(node_snapshot_id):
#     759         ctx = GraphRunContext(self.state, self.deps)
# --> 760         self._next_node = await node.run(ctx)
#     762 if isinstance(self._next_node, End):
#     763     self._snapshot_id = self._next_node.get_snapshot_id()
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_ai/_agent_graph.py:262, in ModelRequestNode.run(self, ctx)
#     257 if self._did_stream:
#     258     # `self._result` gets set when exiting the `stream` contextmanager, so hitting this
#     259     # means that the stream was started but not finished before `run()` was called
#     260     raise exceptions.AgentRunError('You must finish streaming before calling run()')
# --> 262 return await self._make_request(ctx)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_ai/_agent_graph.py:314, in ModelRequestNode._make_request(self, ctx)
#     311     return self._result
#     313 model_settings, model_request_parameters = await self._prepare_request(ctx)
# --> 314 model_response, request_usage = await ctx.deps.model.request(
#     315     ctx.state.message_history, model_settings, model_request_parameters
#     316 )
#     317 ctx.state.usage.incr(_usage.Usage(), requests=1)
#     319 return self._finish_handling(ctx, model_response, request_usage)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_ai/models/openai.py:201, in OpenAIModel.request(self, messages, model_settings, model_request_parameters)
#     194 async def request(
#     195     self,
#     196     messages: list[ModelMessage],
#     197     model_settings: ModelSettings | None,
#     198     model_request_parameters: ModelRequestParameters,
#     199 ) -> tuple[ModelResponse, usage.Usage]:
#     200     check_allow_model_requests()
# --> 201     response = await self._completions_create(
#     202         messages, False, cast(OpenAIModelSettings, model_settings or {}), model_request_parameters
#     203     )
#     204     return self._process_response(response), _map_usage(response)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/pydantic_ai/models/openai.py:273, in OpenAIModel._completions_create(self, messages, stream, model_settings, model_request_parameters)
#     270         openai_messages.append(msg)
#     272 try:
# --> 273     return await self.client.chat.completions.create(
#     274         model=self._model_name,
#     275         messages=openai_messages,
#     276         n=1,
#     277         parallel_tool_calls=model_settings.get('parallel_tool_calls', NOT_GIVEN),
#     278         tools=tools or NOT_GIVEN,
#     279         tool_choice=tool_choice or NOT_GIVEN,
#     280         stream=stream,
#     281         stream_options={'include_usage': True} if stream else NOT_GIVEN,
#     282         max_tokens=model_settings.get('max_tokens', NOT_GIVEN),
#     283         temperature=model_settings.get('temperature', NOT_GIVEN),
#     284         top_p=model_settings.get('top_p', NOT_GIVEN),
#     285         timeout=model_settings.get('timeout', NOT_GIVEN),
#     286         seed=model_settings.get('seed', NOT_GIVEN),
#     287         presence_penalty=model_settings.get('presence_penalty', NOT_GIVEN),
#     288         frequency_penalty=model_settings.get('frequency_penalty', NOT_GIVEN),
#     289         logit_bias=model_settings.get('logit_bias', NOT_GIVEN),
#     290         reasoning_effort=model_settings.get('openai_reasoning_effort', NOT_GIVEN),
#     291     )
#     292 except APIStatusError as e:
#     293     if (status_code := e.status_code) >= 400:
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:2000, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1957 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1958 async def create(
#    1959     self,
#    (...)
#    1997     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1998 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1999     validate_response_format(response_format)
# -> 2000     return await self._post(
#    2001         "/chat/completions",
#    2002         body=await async_maybe_transform(
#    2003             {
#    2004                 "messages": messages,
#    2005                 "model": model,
#    2006                 "audio": audio,
#    2007                 "frequency_penalty": frequency_penalty,
#    2008                 "function_call": function_call,
#    2009                 "functions": functions,
#    2010                 "logit_bias": logit_bias,
#    2011                 "logprobs": logprobs,
#    2012                 "max_completion_tokens": max_completion_tokens,
#    2013                 "max_tokens": max_tokens,
#    2014                 "metadata": metadata,
#    2015                 "modalities": modalities,
#    2016                 "n": n,
#    2017                 "parallel_tool_calls": parallel_tool_calls,
#    2018                 "prediction": prediction,
#    2019                 "presence_penalty": presence_penalty,
#    2020                 "reasoning_effort": reasoning_effort,
#    2021                 "response_format": response_format,
#    2022                 "seed": seed,
#    2023                 "service_tier": service_tier,
#    2024                 "stop": stop,
#    2025                 "store": store,
#    2026                 "stream": stream,
#    2027                 "stream_options": stream_options,
#    2028                 "temperature": temperature,
#    2029                 "tool_choice": tool_choice,
#    2030                 "tools": tools,
#    2031                 "top_logprobs": top_logprobs,
#    2032                 "top_p": top_p,
#    2033                 "user": user,
#    2034                 "web_search_options": web_search_options,
#    2035             },
#    2036             completion_create_params.CompletionCreateParams,
#    2037         ),
#    2038         options=make_request_options(
#    2039             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2040         ),
#    2041         cast_to=ChatCompletion,
#    2042         stream=stream or False,
#    2043         stream_cls=AsyncStream[ChatCompletionChunk],
#    2044     )
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/openai/_base_client.py:1767, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1753 async def post(
#    1754     self,
#    1755     path: str,
#    (...)
#    1762     stream_cls: type[_AsyncStreamT] | None = None,
#    1763 ) -> ResponseT | _AsyncStreamT:
#    1764     opts = FinalRequestOptions.construct(
#    1765         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1766     )
# -> 1767     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/openai/_base_client.py:1461, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1458 else:
#    1459     retries_taken = 0
# -> 1461 return await self._request(
#    1462     cast_to=cast_to,
#    1463     options=options,
#    1464     stream=stream,
#    1465     stream_cls=stream_cls,
#    1466     retries_taken=retries_taken,
#    1467 )
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/openai/_base_client.py:1500, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1497     kwargs["auth"] = self.custom_auth
#    1499 try:
# -> 1500     response = await self._client.send(
#    1501         request,
#    1502         stream=stream or self._should_stream_response_body(request=request),
#    1503         **kwargs,
#    1504     )
#    1505 except httpx.TimeoutException as err:
#    1506     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)
#     391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/http11.py:136, in AsyncHTTP11Connection.handle_async_request(self, request)
#     134     async with Trace("response_closed", logger, request) as trace:
#     135         await self._response_closed()
# --> 136 raise exc
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/http11.py:106, in AsyncHTTP11Connection.handle_async_request(self, request)
#      95     pass
#      97 async with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = await self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/http11.py:177, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = await self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_async/http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/httpcore/_backends/anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/anyio/streams/tls.py:219, in TLSStream.receive(self, max_bytes)
#     218 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 219     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     220     if not data:
#     221         raise EndOfStream
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/anyio/streams/tls.py:162, in TLSStream._call_sslobject_method(self, func, *args)
#     159     if self._write_bio.pending:
#     160         await self.transport_stream.send(self._write_bio.read())
# --> 162     data = await self.transport_stream.receive()
#     163 except EndOfStream:
#     164     self._read_bio.write_eof()
#
# File ~/automagik-agents/.venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py:1254, in SocketStream.receive(self, max_bytes)
#    1248 if (
#    1249     not self._protocol.read_event.is_set()
#    1250     and not self._transport.is_closing()
#    1251     and not self._protocol.is_at_eof
#    1252 ):
#    1253     self._transport.resume_reading()
# -> 1254     await self._protocol.read_event.wait()
#    1255     self._transport.pause_reading()
#    1256 else:
#
# File /usr/lib/python3.10/asyncio/locks.py:214, in Event.wait(self)
#     212 self._waiters.append(fut)
#     213 try:
# --> 214     await fut
#     215     return True
#     216 finally:
#
# CancelledError:

# %%
# Display the results
print(f"\nProcessed {len(family_specs)} product families")
for spec in family_specs:
    print(f"\nFamily: {spec.family_name} (ID: {spec.family_id})")
    print(f"Number of specifications: {len(spec.specs_schema)}")
    print("Sample specifications:")
    sample_specs = list(spec.specs_schema.items())[:3]  # Show first 3 specs
    for name, details in sample_specs:
        print(f"  - {name}: {details['type']} ({details['description'][:50]}...)")
# Out:
# Processed 2 product families
#
# Family: ACESSÓRIOS GABINETE (ID: 65)
# Number of specifications: 10
# Sample specifications:
#   - material_construcao: string (Material de construção do acessório do gabinete...)
#   - cor: string (Cor do acessório do gabinete...)
#   - peso: number (Peso do acessório do gabinete em gramas...)
#
# Family: ACESSÓRIOS OFFICE (ID: 113)
# Number of specifications: 8
# Sample specifications:
#   - material: string (Material do qual o acessório é feito...)
#   - cor: string (Cor do acessório...)
#   - peso: number (Peso do acessório em gramas...)

# %%
import asyncio
import os
import json
from typing import Dict, Any, List, Optional
from pydantic_ai import Agent, RunContext, Tool
import logging
from pydantic import BaseModel, Field
from src.config import settings
from pydantic_ai.common_tools.tavily import tavily_search_tool

tavily_api_key = os.getenv('TAVILY_API_KEY')
assert tavily_api_key is not None

logger = logging.getLogger(__name__)

class ProductInfo(BaseModel):
    """Information extracted about a product."""
    nome: str = Field(description="Nome do produto")
    marca: str = Field(description="Marca do produto")
    especificacoes: Dict[str, Any] = Field(description="Especificações técnicas do produto em formato estruturado")
    descricao: str = Field(description="Descrição geral do produto")
    categoria: str = Field(description="Categoria do produto")
    imagens: List[str] = Field(description="Lista de URLs das imagens do produto")


async def extract_product_info(product_name: str) -> ProductInfo:
    """
    Extract structured information about a product using Tavily search and LLM processing.
    
    Args:
        product_name: Name of the product to search for
        
    Returns:
        Structured product information
    """
    product_extractor = Agent(
        'openai:gpt-4o',
        result_type=ProductInfo,
        system_prompt="""
        You are a product information extraction specialist. Your task is to extract detailed, structured information 
        about computer hardware and peripherals from search results.
        
        Guidelines:
        - Focus on extracting accurate technical specifications
        - Use snake_case for specification keys
        - Structure the data according to the product type (mouse, keyboard, monitor, etc.)
        - Use appropriate data types (string, integer, float, boolean, array)
        - Prefer standardized values where possible
        - Use Portuguese for keys and values
        - Images URL should be in format of a list of URLs
        
        For keyboards, include details like:
        - formato (TKL, Full-Size, etc.)
        - switch_tipo (Linear, Tátil, Clicky)
        - switch_marca (Cherry, Gateron, etc.)
        - conectividade (USB, Bluetooth, etc.)
        
        For mice, include details like:
        - sensor_tipo (Óptico, Laser)
        - dpi_maximo (integer value)
        - ergonomia (Destro, Canhoto, Ambidestro)
        - conectividade (USB, Bluetooth, etc.)
        
        For monitors, include details like:
        - tamanho_tela_polegadas (float value)
        - resolucao_pixels (e.g., "2560x1440")
        - tipo_painel (IPS, VA, TN, etc.)
        - taxa_atualizacao_hz (integer value)
        
        Extract as much relevant information as possible from the search results to create a comprehensive 
        product specification.
        """,
        tools=[tavily_search_tool(tavily_api_key)]
    )
    
    result = await product_extractor.run(
        f"Extract detailed information about this product: {product_name}"
    )
    
    return result.data

# %%
product_name = "Teclado Mecânico Redragon Kumara K552 RGB"
product_info = await extract_product_info(product_name)
print(json.dumps(product_info.model_dump(), indent=2, ensure_ascii=False))
# Out:
# {
#   "nome": "Redragon Kumara K552 RGB",
#   "marca": "Redragon",
#   "especificacoes": {
#     "formato": "TKL",
#     "switch_tipo": "Clicky",
#     "switch_marca": "Outemu Blue",
#     "conectividade": "USB"
#   },
#   "descricao": "O Redragon Kumara K552 RGB é um teclado mecânico compacto Tenkeyless (TKL) projetado para jogos. Possui switches táteis clicky Outemu Blue que são conhecidos por seu som audível de clique e resistência tátil ao pressionar as teclas. O teclado tem iluminação RGB individual por tecla, permitindo uma personalização extensa das luzes. É construído com uma base de liga de metal e ABS que garante durabilidade em condições de jogo intensas. O teclado conta com tecnologia anti-ghosting em todas as 87 teclas e um conector USB banhado a ouro para uma conexão confiável.",
#   "categoria": "Teclado Mecânico",
#   "imagens": [
#     "https://redragonshop.com/products/redragon-kumara-k552?srsltid=AfmBOoojFotTs7UXVxwT2EEGFjxIAH3jDPRcgs6SLnotkS-JD0VbYE8J",
#     "https://api.bestbuy.com/click/-/6458719/pdp"
#   ]
# }
